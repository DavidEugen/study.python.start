# %% [markdown]
# # DataFrame

# %% [markdown]
# ## DataFrame 만들기

# %% [markdown]
# 기본 형태 : pd.DataFrame(data, index, cloums)
# - index와 columns는 변수를 리스트로 받음
# - data는 list, dictionary, Series 될 수 있음
# - dictionary로 생성시 index 혹은 col값 설정 주의

# %%
 import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %% [markdown]
# ### list로 DataFrame 만들기

# %%
ls = ["a", "b", "c", "d", "e"]

ls_df = pd.DataFrame(ls, index=['영수','영철','영자','영희','영삼'], columns=["성적"])
ls_df
# Out:
#    성적
# 영수  a
# 영철  b
# 영자  c
# 영희  d
# 영삼  e

# %% [markdown]
# #### index 와 Column 생성 방법

# %% [markdown]
# 상기와 같이 작성 하기도 하지만, 리스트 생성뒤 index, columns 설정 하는 방법도 잘 쓰인다

# %%
ls_df = pd.DataFrame(ls)
ls_df.index = ['영수','영철','영자','영희','영삼']
ls_df.columns = ["성적"] 
ls_df
# Out:
#    성적
# 영수  a
# 영철  b
# 영자  c
# 영희  d
# 영삼  e

# %% [markdown]
# colums 의 형태는 list인 점 주의

# %% [markdown]
# ### dictionary로 생성

# %%
dic = {"영수": 101, "영철": 102, "영삼": 103, "영자": 104, "영호": 105}

dic_df = pd.DataFrame(dic)
dic_df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2380\199721173.py in <module>
#       1 dic = {"영수": 101, "영철": 102, "영삼": 103, "영자": 104, "영호": 105}
#       2
# ----> 3 dic_df = pd.DataFrame(dic)
#       4 dic_df
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     634         elif isinstance(data, dict):
#     635             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 636             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     637         elif isinstance(data, ma.MaskedArray):
#     638             import numpy.ma.mrecords as mrecords
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in dict_to_mgr(data, index, columns, dtype, typ, copy)
# ...

# %% [markdown]
# dictionary로 생성시 인덱스 지정 하지 않으면 문법적 오류 생성...

# %%
dic_df = pd.DataFrame(dic, index = [0])  
dic_df
# Out:
# Int64Index([0], dtype='int64')

# %%
dic_df.columns = ["성적"]
dic_df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2380\2588718834.py in <module>
# ----> 1 dic_df.columns = ["성적"]
#       2 dic_df
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __setattr__(self, name, value)
#    5586         try:
#    5587             object.__getattribute__(self, name)
# -> 5588             return object.__setattr__(self, name, value)
#    5589         except AttributeError:
#    5590             pass
#
# ~\anaconda3\lib\site-packages\pandas\_libs\properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _set_axis(self, axis, labels)
#     767     def _set_axis(self, axis: int, labels: Index) -> None:
#     768         labels = ensure_index(labels)
# --> 769         self._mgr.set_axis(axis, labels)
#     770         self._clear_item_cache()
# ...

# %%
type(dic.values())
# Out:
# dict_values

# %%
dic.values()
# Out:
# dict_values([101, 102, 103, 104, 105])

# %%
dic_df = pd.DataFrame(dic.values())
dic_df
# Out:
#      0
# 0  101
# 1  102
# 2  103
# 3  104
# 4  105

# %%
dic_df.index = dic.keys()
dic_df.columns = ['성적']
dic_df
# Out:
#      성적
# 영수  101
# 영철  102
# 영삼  103
# 영자  104
# 영호  105

# %% [markdown]
# ### Series로 생성하기

# %%
samsung = pd.read_csv('삼성전자 종가.csv', index_col = 0, squeeze = True, header = 0)
samsung_df = pd.DataFrame(samsung)
samsung_df
# Out:
# C:\Users\proyj\AppData\Local\Temp\ipykernel_2380\4061878558.py:1: FutureWarning: The squeeze argument has been deprecated and will be removed in a future version. Append .squeeze("columns") to the call to squeeze.
#
#
#   samsung = pd.read_csv('삼성전자 종가.csv', index_col = 0, squeeze = True, header = 0)
#             Close
# Date
# 2018-01-02  51020
# 2018-01-03  51620
# 2018-01-04  51080
# 2018-01-05  52120
# 2018-01-08  52020
# ...           ...
# 2021-12-13  76800
# 2021-12-14  77000
# 2021-12-15  77600
# 2021-12-16  77800
# 2021-12-17  78000
#
# [977 rows x 1 columns]

# %%
type(samsung_df)
# Out:
# pandas.core.frame.DataFrame

# %%
samsung_df.index
# Out:
# Index(['2018-01-02', '2018-01-03', '2018-01-04', '2018-01-05', '2018-01-08',
#        '2018-01-09', '2018-01-10', '2018-01-11', '2018-01-12', '2018-01-15',
#        ...
#        '2021-12-06', '2021-12-07', '2021-12-08', '2021-12-09', '2021-12-10',
#        '2021-12-13', '2021-12-14', '2021-12-15', '2021-12-16', '2021-12-17'],
#       dtype='object', name='Date', length=977)

# %%
samsung_df.columns
# Out:
# Index(['Close'], dtype='object')

# %% [markdown]
# ## 외부 데이터에서 가져오기

# %%
import pandas as pd

# %% [markdown]
# cf.
# Series :
# pd.read_csv(path, index_col, header, squeeze = True)
#
# DataFrame :
# pd.read_csv(path, index_col, header, squeeze = False)
# pd.read_csv(path, index_col, header)

# %%
lotte_che = pd.read_csv('롯데케미칼.csv', index_col = 'Date')
lotte_che
# Out:
#               Open    High     Low   Close  Volume    Change
# Date
# 2018-01-02  368000  370000  360500  360500   92533 -0.020380
# 2018-01-03  360000  368500  360000  363000   81340  0.006935
# 2018-01-04  367500  367500  349000  349000  190391 -0.038567
# 2018-01-05  351000  352000  348000  351500   99268  0.007163
# 2018-01-08  359000  383500  358000  383500  490208  0.091038
# ...            ...     ...     ...     ...     ...       ...
# 2021-12-16  233000  234000  224500  228000  144647 -0.012987
# 2021-12-17  227000  235000  226500  234500  138945  0.028509
# 2021-12-20  232000  233500  228000  229500   90630 -0.021322
# 2021-12-21  232000  232500  227000  229500   98669  0.000000
# 2021-12-22  229000  230000  225000  225000   99419 -0.019608
#
# [980 rows x 6 columns]

# %%
lotte_che = pd.read_csv('롯데케미칼.csv', index_col = 'High')
lotte_che
# Out:
#               Date    Open     Low   Close  Volume    Change
# High
# 370000  2018-01-02  368000  360500  360500   92533 -0.020380
# 368500  2018-01-03  360000  360000  363000   81340  0.006935
# 367500  2018-01-04  367500  349000  349000  190391 -0.038567
# 352000  2018-01-05  351000  348000  351500   99268  0.007163
# 383500  2018-01-08  359000  358000  383500  490208  0.091038
# ...            ...     ...     ...     ...     ...       ...
# 234000  2021-12-16  233000  224500  228000  144647 -0.012987
# 235000  2021-12-17  227000  226500  234500  138945  0.028509
# 233500  2021-12-20  232000  228000  229500   90630 -0.021322
# 232500  2021-12-21  232000  227000  229500   98669  0.000000
# 230000  2021-12-22  229000  225000  225000   99419 -0.019608
#
# [980 rows x 6 columns]

# %%
lotte_che = pd.read_csv('롯데케미칼.csv', index_col = 0,header = 0)
lotte_che
# Out:
#               Open    High     Low   Close  Volume    Change
# Date
# 2018-01-02  368000  370000  360500  360500   92533 -0.020380
# 2018-01-03  360000  368500  360000  363000   81340  0.006935
# 2018-01-04  367500  367500  349000  349000  190391 -0.038567
# 2018-01-05  351000  352000  348000  351500   99268  0.007163
# 2018-01-08  359000  383500  358000  383500  490208  0.091038
# ...            ...     ...     ...     ...     ...       ...
# 2021-12-16  233000  234000  224500  228000  144647 -0.012987
# 2021-12-17  227000  235000  226500  234500  138945  0.028509
# 2021-12-20  232000  233500  228000  229500   90630 -0.021322
# 2021-12-21  232000  232500  227000  229500   98669  0.000000
# 2021-12-22  229000  230000  225000  225000   99419 -0.019608
#
# [980 rows x 6 columns]

# %% [markdown]
# ## DataFrame 행과 열 선택 하기

# %% [markdown]
# [] -> Series , [[]] -> DataFrame

# %% [markdown]
# ### 행 선택하기

# %% [markdown]
# #### lable로 선택하기

# %% [markdown]
# #### dataFrame.loc[행label]

# %%
lotte_che.loc['2018-01-02']
# Out:
# Open      368000.00000
# High      370000.00000
# Low       360500.00000
# Close     360500.00000
# Volume     92533.00000
# Change        -0.02038
# Name: 2018-01-02, dtype: float64

# %%
type(lotte_che.loc['2018-01-02'] )
# Out:
# pandas.core.series.Series

# %% [markdown]
# #### dataFrame.loc[행label:행label]

# %%
lotte_che.loc['2018-01-02':'2018-01-08']
# Out:
#               Open    High     Low   Close  Volume    Change
# Date
# 2018-01-02  368000  370000  360500  360500   92533 -0.020380
# 2018-01-03  360000  368500  360000  363000   81340  0.006935
# 2018-01-04  367500  367500  349000  349000  190391 -0.038567
# 2018-01-05  351000  352000  348000  351500   99268  0.007163
# 2018-01-08  359000  383500  358000  383500  490208  0.091038

# %% [markdown]
# #### dataFrame.loc[[행label,행label...]]

# %%
lotte_che.loc[['2021-12-16', '2021-12-17', '2021-12-20']]
# Out:
#               Open    High     Low   Close  Volume    Change
# Date
# 2021-12-16  233000  234000  224500  228000  144647 -0.012987
# 2021-12-17  227000  235000  226500  234500  138945  0.028509
# 2021-12-20  232000  233500  228000  229500   90630 -0.021322

# %%
type(lotte_che.loc[['2021-12-16', '2021-12-17', '2021-12-20']])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# #### 사용 불가 dataFrame.loc[행label,행label]

# %%
lotte_che.loc['2021-12-16', '2021-12-17', '2021-12-20']
# Out:
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2380\3481907253.py in <module>
# ----> 1 lotte_che.loc['2021-12-16', '2021-12-17', '2021-12-20']
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     959             if self._is_scalar_access(key):
#     960                 return self.obj._get_value(*key, takeable=self._takeable)
# --> 961             return self._getitem_tuple(key)
#     962         else:
#     963             # we by definition only have the 0th axis
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1141
#    1142         # no multi-index, so validate all of the indexers
# -> 1143         tup = self._validate_tuple_indexer(tup)
#    1144
#    1145         # ugly hack for GH #836
#
# ...

# %% [markdown]
# #### 사용 불가 dataFrame.loc[[행label:행label]]

# %%
lotte_che.loc[['2021-12-16':'2021-12-20']]
# Out:
#   File "C:\Users\proyj\AppData\Local\Temp\ipykernel_2380\1126601001.py", line 1
#     lotte_che.loc[['2021-12-16':'2021-12-20']]
#                                ^
# SyntaxError: invalid syntax

# %% [markdown]
# #### index로 선택하기

# %% [markdown]
# #### dataFrame.iloc[행index]

# %%
lotte_che.iloc[0]
# Out:
# Open      368000.00000
# High      370000.00000
# Low       360500.00000
# Close     360500.00000
# Volume     92533.00000
# Change        -0.02038
# Name: 2018-01-02, dtype: float64

# %% [markdown]
# #### dataFrame.iloc[행index:행index]

# %%
lotte_che.iloc[0:4]
# Out:
#               Open    High     Low   Close  Volume    Change
# Date
# 2018-01-02  368000  370000  360500  360500   92533 -0.020380
# 2018-01-03  360000  368500  360000  363000   81340  0.006935
# 2018-01-04  367500  367500  349000  349000  190391 -0.038567
# 2018-01-05  351000  352000  348000  351500   99268  0.007163

# %% [markdown]
# #### dataFrame[행index:행index]

# %%
lotte_che[0:4]
# Out:
#               Open    High     Low   Close  Volume    Change
# Date
# 2018-01-02  368000  370000  360500  360500   92533 -0.020380
# 2018-01-03  360000  368500  360000  363000   81340  0.006935
# 2018-01-04  367500  367500  349000  349000  190391 -0.038567
# 2018-01-05  351000  352000  348000  351500   99268  0.007163

# %% [markdown]
# #### dataFrame.iloc[[행index,행index...]]

# %%
lotte_che.iloc[[0,100, 56]]
# Out:
#               Open    High     Low   Close  Volume    Change
# Date
# 2018-01-02  368000  370000  360500  360500   92533 -0.020380
# 2018-05-30  371000  376500  361500  363000  107516 -0.026810
# 2018-03-26  423000  440500  423000  440500   93789  0.024419

# %% [markdown]
# #### 사용 불가 dataframe[행label], dataframe[[행label]]

# %%
lotte_che['2018-01-02']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '2018-01-02'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
lotte_che[['2018-01-02']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2380\3977271013.py in <module>
# ----> 1 lotte_che[['2018-01-02']]
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3509             if is_iterator(key):
#    3510                 key = list(key)
# -> 3511             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3512
#    3513         # take() does not accept boolean indexers
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in _get_indexer_strict(self, key, axis_name)
#    5794             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    5795
# -> 5796         self._raise_if_missing(keyarr, indexer, axis_name)
#    5797
#    5798         keyarr = self.take(indexer)
#
# ...

# %% [markdown]
# #### 사용 불가 dataFrame.iloc[[행index:행index]]

# %%
lotte_che.iloc[[0:4]]
# Out:
#   File "C:\Users\proyj\AppData\Local\Temp\ipykernel_2380\280868775.py", line 1
#     lotte_che.iloc[[0:4]]
#                      ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### 열 선택하기

# %% [markdown]
# #### label로 선택하기

# %% [markdown]
# #### dataframe[열label]

# %%
lotte_che['Open']
# Out:
# Date
# 2018-01-02    368000
# 2018-01-03    360000
# 2018-01-04    367500
# 2018-01-05    351000
# 2018-01-08    359000
#                ...
# 2021-12-16    233000
# 2021-12-17    227000
# 2021-12-20    232000
# 2021-12-21    232000
# 2021-12-22    229000
# Name: Open, Length: 980, dtype: int64

# %%
type(lotte_che['Open'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# #### dataframe[[열label]]

# %%
lotte_che[['Open']]
# Out:
#               Open
# Date
# 2018-01-02  368000
# 2018-01-03  360000
# 2018-01-04  367500
# 2018-01-05  351000
# 2018-01-08  359000
# ...            ...
# 2021-12-16  233000
# 2021-12-17  227000
# 2021-12-20  232000
# 2021-12-21  232000
# 2021-12-22  229000
#
# [980 rows x 1 columns]

# %%
type(lotte_che[['Open']])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# #### dataFrame[[열label,열label...]]

# %%
lotte_che[['Open', 'High']]
# Out:
#               Open    High
# Date
# 2018-01-02  368000  370000
# 2018-01-03  360000  368500
# 2018-01-04  367500  367500
# 2018-01-05  351000  352000
# 2018-01-08  359000  383500
# ...            ...     ...
# 2021-12-16  233000  234000
# 2021-12-17  227000  235000
# 2021-12-20  232000  233500
# 2021-12-21  232000  232500
# 2021-12-22  229000  230000
#
# [980 rows x 2 columns]

# %% [markdown]
# #### 사용 불가 dataframe[열label,열label]

# %%
lotte_che['Open', 'High']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('Open', 'High')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %% [markdown]
# #### index로 선택하기

# %% [markdown]
# #### dataFrame[dataFrame.colums[[열index,열index...]]

# %%
lotte_che[lotte_che.columns[[5, 1, 2]]]
# Out:
#               Change    High     Low
# Date
# 2018-01-02 -0.020380  370000  360500
# 2018-01-03  0.006935  368500  360000
# 2018-01-04 -0.038567  367500  349000
# 2018-01-05  0.007163  352000  348000
# 2018-01-08  0.091038  383500  358000
# ...              ...     ...     ...
# 2021-12-16 -0.012987  234000  224500
# 2021-12-17  0.028509  235000  226500
# 2021-12-20 -0.021322  233500  228000
# 2021-12-21  0.000000  232500  227000
# 2021-12-22 -0.019608  230000  225000
#
# [980 rows x 3 columns]

# %% [markdown]
# #### dataFrame[dataFrame.colums[열index : 열index]]

# %%
lotte_che.columns[0:2]
# Out:
# Index(['Open', 'High'], dtype='object')

# %%
lotte_che[lotte_che.columns[0:2]]
# Out:
#               Open    High
# Date
# 2018-01-02  368000  370000
# 2018-01-03  360000  368500
# 2018-01-04  367500  367500
# 2018-01-05  351000  352000
# 2018-01-08  359000  383500
# ...            ...     ...
# 2021-12-16  233000  234000
# 2021-12-17  227000  235000
# 2021-12-20  232000  233500
# 2021-12-21  232000  232500
# 2021-12-22  229000  230000
#
# [980 rows x 2 columns]

# %%
lotte_che[lotte_che.columns[:-1]]
# Out:
#               Open    High     Low   Close  Volume
# Date
# 2018-01-02  368000  370000  360500  360500   92533
# 2018-01-03  360000  368500  360000  363000   81340
# 2018-01-04  367500  367500  349000  349000  190391
# 2018-01-05  351000  352000  348000  351500   99268
# 2018-01-08  359000  383500  358000  383500  490208
# ...            ...     ...     ...     ...     ...
# 2021-12-16  233000  234000  224500  228000  144647
# 2021-12-17  227000  235000  226500  234500  138945
# 2021-12-20  232000  233500  228000  229500   90630
# 2021-12-21  232000  232500  227000  229500   98669
# 2021-12-22  229000  230000  225000  225000   99419
#
# [980 rows x 5 columns]

# %% [markdown]
# #### 사용 불가 dataFrame[열index]

# %%
lotte_che[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %% [markdown]
# #### 사용 불가 dataFrame[열index] -> 행index로 작동

# %%
lotte_che[0:5]
# Out:
#               Open    High     Low   Close  Volume    Change
# Date
# 2018-01-02  368000  370000  360500  360500   92533 -0.020380
# 2018-01-03  360000  368500  360000  363000   81340  0.006935
# 2018-01-04  367500  367500  349000  349000  190391 -0.038567
# 2018-01-05  351000  352000  348000  351500   99268  0.007163
# 2018-01-08  359000  383500  358000  383500  490208  0.091038

# %% [markdown]
# ## 열 추가 하기

# %%
lotte_che
# Out:
#               Open    High     Low   Close  Volume    Change
# Date
# 2018-01-02  368000  370000  360500  360500   92533 -0.020380
# 2018-01-03  360000  368500  360000  363000   81340  0.006935
# 2018-01-04  367500  367500  349000  349000  190391 -0.038567
# 2018-01-05  351000  352000  348000  351500   99268  0.007163
# 2018-01-08  359000  383500  358000  383500  490208  0.091038
# ...            ...     ...     ...     ...     ...       ...
# 2021-12-16  233000  234000  224500  228000  144647 -0.012987
# 2021-12-17  227000  235000  226500  234500  138945  0.028509
# 2021-12-20  232000  233500  228000  229500   90630 -0.021322
# 2021-12-21  232000  232500  227000  229500   98669  0.000000
# 2021-12-22  229000  230000  225000  225000   99419 -0.019608
#
# [980 rows x 6 columns]

# %%
lotte_che = lotte_che[lotte_che.columns[:-1]]
lotte_che
# Out:
#               Open    High     Low   Close  Volume
# Date
# 2018-01-02  368000  370000  360500  360500   92533
# 2018-01-03  360000  368500  360000  363000   81340
# 2018-01-04  367500  367500  349000  349000  190391
# 2018-01-05  351000  352000  348000  351500   99268
# 2018-01-08  359000  383500  358000  383500  490208
# ...            ...     ...     ...     ...     ...
# 2021-12-16  233000  234000  224500  228000  144647
# 2021-12-17  227000  235000  226500  234500  138945
# 2021-12-20  232000  233500  228000  229500   90630
# 2021-12-21  232000  232500  227000  229500   98669
# 2021-12-22  229000  230000  225000  225000   99419
#
# [980 rows x 5 columns]

# %%
lotte_che['Return'] = lotte_che['Close'].pct_change().fillna(0)
lotte_che
# Out:
#               Open    High     Low   Close  Volume    Return
# Date
# 2018-01-02  368000  370000  360500  360500   92533  0.000000
# 2018-01-03  360000  368500  360000  363000   81340  0.006935
# 2018-01-04  367500  367500  349000  349000  190391 -0.038567
# 2018-01-05  351000  352000  348000  351500   99268  0.007163
# 2018-01-08  359000  383500  358000  383500  490208  0.091038
# ...            ...     ...     ...     ...     ...       ...
# 2021-12-16  233000  234000  224500  228000  144647 -0.012987
# 2021-12-17  227000  235000  226500  234500  138945  0.028509
# 2021-12-20  232000  233500  228000  229500   90630 -0.021322
# 2021-12-21  232000  232500  227000  229500   98669  0.000000
# 2021-12-22  229000  230000  225000  225000   99419 -0.019608
#
# [980 rows x 6 columns]

# %% [markdown]
# ## 행 추가 하기

# %% [markdown]
# ### 행 추가시 Demension 맞게!!

# %% [markdown]
# #### 차원 안 맞을 시 오류

# %%
lotte_che.loc['2021-12-23'] = 0, 0
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2380\4294949381.py in <module>
# ----> 1 lotte_che.loc['2021-12-23'] = 0, 0
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __setitem__(self, key, value)
#     714
#     715         iloc = self if self.name == "iloc" else self.obj.iloc
# --> 716         iloc._setitem_with_indexer(indexer, value, self.name)
#     717
#     718     def _validate_key(self, key, axis: int):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _setitem_with_indexer(self, indexer, value, name)
#    1683
#    1684             if missing:
# -> 1685                 self._setitem_with_indexer_missing(indexer, value)
#    1686                 return
#    1687
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _setitem_with_indexer_missing(self, indexer, value)
# ...

# %%
lotte_che.loc['2021-12-23'] = [0, 0]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2380\264947480.py in <module>
# ----> 1 lotte_che.loc['2021-12-23'] = [0, 0]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __setitem__(self, key, value)
#     714
#     715         iloc = self if self.name == "iloc" else self.obj.iloc
# --> 716         iloc._setitem_with_indexer(indexer, value, self.name)
#     717
#     718     def _validate_key(self, key, axis: int):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _setitem_with_indexer(self, indexer, value, name)
#    1683
#    1684             if missing:
# -> 1685                 self._setitem_with_indexer_missing(indexer, value)
#    1686                 return
#    1687
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _setitem_with_indexer_missing(self, indexer, value)
# ...

# %%
lotte_che.shape
# Out:
# (980, 6)

# %%
lotte_che.loc['2021-12-23'] = [0,0,0,0,0,0] # 차원이 맞아야 할당 가능 하다
lotte_che
# Out:
#               Open    High     Low   Close  Volume    Return
# Date
# 2018-01-02  368000  370000  360500  360500   92533  0.000000
# 2018-01-03  360000  368500  360000  363000   81340  0.006935
# 2018-01-04  367500  367500  349000  349000  190391 -0.038567
# 2018-01-05  351000  352000  348000  351500   99268  0.007163
# 2018-01-08  359000  383500  358000  383500  490208  0.091038
# ...            ...     ...     ...     ...     ...       ...
# 2021-12-17  227000  235000  226500  234500  138945  0.028509
# 2021-12-20  232000  233500  228000  229500   90630 -0.021322
# 2021-12-21  232000  232500  227000  229500   98669  0.000000
# 2021-12-22  229000  230000  225000  225000   99419 -0.019608
# 2021-12-23       0       0       0       0       0  0.000000
#
# [981 rows x 6 columns]

# %%
lotte_che.loc['2021-12-23'] = [100,100,100,100,100,100]
lotte_che
# Out:
#               Open    High     Low   Close  Volume      Return
# Date
# 2018-01-02  368000  370000  360500  360500   92533    0.000000
# 2018-01-03  360000  368500  360000  363000   81340    0.006935
# 2018-01-04  367500  367500  349000  349000  190391   -0.038567
# 2018-01-05  351000  352000  348000  351500   99268    0.007163
# 2018-01-08  359000  383500  358000  383500  490208    0.091038
# ...            ...     ...     ...     ...     ...         ...
# 2021-12-17  227000  235000  226500  234500  138945    0.028509
# 2021-12-20  232000  233500  228000  229500   90630   -0.021322
# 2021-12-21  232000  232500  227000  229500   98669    0.000000
# 2021-12-22  229000  230000  225000  225000   99419   -0.019608
# 2021-12-23     100     100     100     100     100  100.000000
#
# [981 rows x 6 columns]

# %%
lotte_che.loc['2021-12-23'] = 0 # scalar는 Braodcasting?
lotte_che
# Out:
#               Open    High     Low   Close  Volume    Return
# Date
# 2018-01-02  368000  370000  360500  360500   92533  0.000000
# 2018-01-03  360000  368500  360000  363000   81340  0.006935
# 2018-01-04  367500  367500  349000  349000  190391 -0.038567
# 2018-01-05  351000  352000  348000  351500   99268  0.007163
# 2018-01-08  359000  383500  358000  383500  490208  0.091038
# ...            ...     ...     ...     ...     ...       ...
# 2021-12-17  227000  235000  226500  234500  138945  0.028509
# 2021-12-20  232000  233500  228000  229500   90630 -0.021322
# 2021-12-21  232000  232500  227000  229500   98669  0.000000
# 2021-12-22  229000  230000  225000  225000   99419 -0.019608
# 2021-12-23       0       0       0       0       0  0.000000
#
# [981 rows x 6 columns]

# %% [markdown]
# ## 행과 열 예제

# %%
  def return_fn(df):
        df_close = df['Close']
        df_close['Return'] = df_close.pct_change().fillna(0)
        return df_close

# %%
df = return_fn(df = lotte_che)
df
# Out:
# C:\Users\proyj\AppData\Local\Temp\ipykernel_2380\2890281629.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_close['Return'] = df_close.pct_change().fillna(0)
# Date
# 2018-01-02                                               360500
# 2018-01-03                                               363000
# 2018-01-04                                               349000
# 2018-01-05                                               351500
# 2018-01-08                                               383500
#                                     ...
# 2021-12-20                                               229500
# 2021-12-21                                               229500
# 2021-12-22                                               225000
# ...

# %%
df = return_fn(lotte_che)
df
# Out:
# C:\Users\proyj\AppData\Local\Temp\ipykernel_2380\2890281629.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_close['Return'] = df_close.pct_change().fillna(0)
# Date
# 2018-01-02                                               360500
# 2018-01-03                                               363000
# 2018-01-04                                               349000
# 2018-01-05                                               351500
# 2018-01-08                                               383500
#                                     ...
# 2021-12-20                                               229500
# 2021-12-21                                               229500
# 2021-12-22                                               225000
# ...

# %%
def return_fn(df):
        df_close = df[['Close']]
        df_close['Return'] = df_close.pct_change().fillna(0)
        return df_close

# %%
df = return_fn(df = lotte_che)
df
# Out:
# C:\Users\proyj\AppData\Local\Temp\ipykernel_2380\2300554577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_close['Return'] = df_close.pct_change().fillna(0)
#              Close    Return
# Date
# 2018-01-02  360500  0.000000
# 2018-01-03  363000  0.006935
# 2018-01-04  349000 -0.038567
# 2018-01-05  351500  0.007163
# 2018-01-08  383500  0.091038
# ...            ...       ...
# 2021-12-17  234500  0.028509
# 2021-12-20  229500 -0.021322
# 2021-12-21  229500  0.000000
# 2021-12-22  225000 -0.019608
# 2021-12-23       0 -1.000000
#
# [981 rows x 2 columns]

# %% [markdown]
# ## DataFrame 합치기

# %% [markdown]
# concat, join, merge

# %%
import pandas as pd
#pd.set_option('display.max_rows', None)
pd.set_option('display.max_rows', 200)

# %%
df_samsung = pd.read_excel('samsung_naver_excel.xlsx', sheet_name = 'samsung', index_col = 0)
df_samsung
# Out:
#              Open   High    Low  Close    Volume    Change
# Date
# 2018-01-02  51380  51400  50780  51020    169485  0.001177
# 2018-01-03  52540  52560  51420  51620    200270  0.011760
# 2018-01-04  52120  52180  50640  51080    233909 -0.010461
# 2018-01-05  51300  52120  51200  52120    189623  0.020360
# 2018-01-08  52400  52520  51500  52020    167673 -0.001919
# ...           ...    ...    ...    ...       ...       ...
# 2020-12-23  72400  74000  72300  73900  19411326  0.022130
# 2020-12-24  74100  78800  74000  77800  32502870  0.052774
# 2020-12-28  79000  80100  78200  78700  40085044  0.011568
# 2020-12-29  78800  78900  77300  78300  30339449 -0.005083
# 2020-12-30  77400  81300  77300  81000  29417421  0.034483
#
# [738 rows x 6 columns]

# %%
df_naver = pd.read_excel('samsung_naver_excel.xlsx', sheet_name = 'naver', index_col = 0)
df_naver
# Out:
#               Open    High     Low   Close  Volume    Change
# Date
# 2016-01-04  130182  131784  126578  126579   93272 -0.039511
# 2016-01-05  126778  128580  126378  127580   69456  0.007908
# 2016-01-06  129181  129181  124575  124776   95682 -0.021978
# 2016-01-07  125377  132187  125377  130585  125253  0.046555
# 2016-01-08  130585  131987  128582  130585   63922  0.000000
# ...            ...     ...     ...     ...     ...       ...
# 2019-12-23  185000  185500  182000  184000  250256  0.002725
# 2019-12-24  184000  184000  179000  182000  193440 -0.010870
# 2019-12-26  181500  183000  179000  180500  173426 -0.008242
# 2019-12-27  182000  185000  179000  183500  323473  0.016620
# 2019-12-30  183500  190000  183500  186500  376541  0.016349
#
# [979 rows x 6 columns]

# %%
df = pd.concat([df_naver, df_samsung])
df
# Out:
#               Open    High     Low   Close    Volume    Change
# Date
# 2016-01-04  130182  131784  126578  126579     93272 -0.039511
# 2016-01-05  126778  128580  126378  127580     69456  0.007908
# 2016-01-06  129181  129181  124575  124776     95682 -0.021978
# 2016-01-07  125377  132187  125377  130585    125253  0.046555
# 2016-01-08  130585  131987  128582  130585     63922  0.000000
# ...            ...     ...     ...     ...       ...       ...
# 2020-12-23   72400   74000   72300   73900  19411326  0.022130
# 2020-12-24   74100   78800   74000   77800  32502870  0.052774
# 2020-12-28   79000   80100   78200   78700  40085044  0.011568
# 2020-12-29   78800   78900   77300   78300  30339449 -0.005083
# 2020-12-30   77400   81300   77300   81000  29417421  0.034483
#
# [1717 rows x 6 columns]

# %%
df = pd.concat([df_samsung, df_naver])
df
# Out:
#               Open    High     Low   Close  Volume    Change
# Date
# 2018-01-02   51380   51400   50780   51020  169485  0.001177
# 2018-01-03   52540   52560   51420   51620  200270  0.011760
# 2018-01-04   52120   52180   50640   51080  233909 -0.010461
# 2018-01-05   51300   52120   51200   52120  189623  0.020360
# 2018-01-08   52400   52520   51500   52020  167673 -0.001919
# ...            ...     ...     ...     ...     ...       ...
# 2019-12-23  185000  185500  182000  184000  250256  0.002725
# 2019-12-24  184000  184000  179000  182000  193440 -0.010870
# 2019-12-26  181500  183000  179000  180500  173426 -0.008242
# 2019-12-27  182000  185000  179000  183500  323473  0.016620
# 2019-12-30  183500  190000  183500  186500  376541  0.016349
#
# [1717 rows x 6 columns]

# %%
df = pd.concat([df_naver, df_samsung], keys=['naver', 'samsung'], names=['stock', '날짜'])

df.loc[('samsung','2018-03-15')]
# Out:
# Open       52000.00000
# High       52020.00000
# Low        51020.00000
# Close      51540.00000
# Volume    177649.00000
# Change        -0.00425
# Name: (samsung, 2018-03-15 00:00:00), dtype: float64

# %%
df
# Out:
#                       Open    High     Low   Close    Volume    Change
# stock   날짜
# naver   2016-01-04  130182  131784  126578  126579     93272 -0.039511
#         2016-01-05  126778  128580  126378  127580     69456  0.007908
#         2016-01-06  129181  129181  124575  124776     95682 -0.021978
#         2016-01-07  125377  132187  125377  130585    125253  0.046555
#         2016-01-08  130585  131987  128582  130585     63922  0.000000
# ...                    ...     ...     ...     ...       ...       ...
# samsung 2020-12-23   72400   74000   72300   73900  19411326  0.022130
#         2020-12-24   74100   78800   74000   77800  32502870  0.052774
#         2020-12-28   79000   80100   78200   78700  40085044  0.011568
#         2020-12-29   78800   78900   77300   78300  30339449 -0.005083
#         2020-12-30   77400   81300   77300   81000  29417421  0.034483
#
# [1717 rows x 6 columns]

# %%
df = pd.concat([df_naver, df_samsung], keys=['naver', 'samsung'], names=['stock', '날짜'], axis=0)
df
# Out:
#                       Open    High     Low   Close    Volume    Change
# stock   날짜
# naver   2016-01-04  130182  131784  126578  126579     93272 -0.039511
#         2016-01-05  126778  128580  126378  127580     69456  0.007908
#         2016-01-06  129181  129181  124575  124776     95682 -0.021978
#         2016-01-07  125377  132187  125377  130585    125253  0.046555
#         2016-01-08  130585  131987  128582  130585     63922  0.000000
# ...                    ...     ...     ...     ...       ...       ...
# samsung 2020-12-23   72400   74000   72300   73900  19411326  0.022130
#         2020-12-24   74100   78800   74000   77800  32502870  0.052774
#         2020-12-28   79000   80100   78200   78700  40085044  0.011568
#         2020-12-29   78800   78900   77300   78300  30339449 -0.005083
#         2020-12-30   77400   81300   77300   81000  29417421  0.034483
#
# [1717 rows x 6 columns]

# %%
df = pd.concat([df_naver, df_samsung], keys=['naver', 'samsung'], names=['stock', '날짜'], axis=1)
df
# Out:
# stock          naver                                                    \
# 날짜              Open      High       Low     Close    Volume    Change
# Date
# 2016-01-04  130182.0  131784.0  126578.0  126579.0   93272.0 -0.039511
# 2016-01-05  126778.0  128580.0  126378.0  127580.0   69456.0  0.007908
# 2016-01-06  129181.0  129181.0  124575.0  124776.0   95682.0 -0.021978
# 2016-01-07  125377.0  132187.0  125377.0  130585.0  125253.0  0.046555
# 2016-01-08  130585.0  131987.0  128582.0  130585.0   63922.0  0.000000
# ...              ...       ...       ...       ...       ...       ...
# 2020-12-23       NaN       NaN       NaN       NaN       NaN       NaN
# 2020-12-24       NaN       NaN       NaN       NaN       NaN       NaN
# 2020-12-28       NaN       NaN       NaN       NaN       NaN       NaN
# 2020-12-29       NaN       NaN       NaN       NaN       NaN       NaN
# 2020-12-30       NaN       NaN       NaN       NaN       NaN       NaN
#
# stock       samsung
# ...

# %%
df = pd.concat([df_naver, df_samsung], keys=['naver', 'samsung'], names=['stock', '날짜'], axis=1, join='outer')
df
# Out:
# stock          naver                                                    \
# 날짜              Open      High       Low     Close    Volume    Change
# Date
# 2016-01-04  130182.0  131784.0  126578.0  126579.0   93272.0 -0.039511
# 2016-01-05  126778.0  128580.0  126378.0  127580.0   69456.0  0.007908
# 2016-01-06  129181.0  129181.0  124575.0  124776.0   95682.0 -0.021978
# 2016-01-07  125377.0  132187.0  125377.0  130585.0  125253.0  0.046555
# 2016-01-08  130585.0  131987.0  128582.0  130585.0   63922.0  0.000000
# ...              ...       ...       ...       ...       ...       ...
# 2020-12-23       NaN       NaN       NaN       NaN       NaN       NaN
# 2020-12-24       NaN       NaN       NaN       NaN       NaN       NaN
# 2020-12-28       NaN       NaN       NaN       NaN       NaN       NaN
# 2020-12-29       NaN       NaN       NaN       NaN       NaN       NaN
# 2020-12-30       NaN       NaN       NaN       NaN       NaN       NaN
#
# stock       samsung
# ...

# %%
df = pd.concat([df_naver, df_samsung], keys=['naver', 'samsung'], names=['stock', '날짜'], axis=1, join='inner')
df
# Out:
# stock        naver                                           samsung         \
# 날짜            Open    High     Low   Close  Volume    Change    Open   High
# Date
# 2018-01-02  174447  177251  174247  177251   93587  0.017240   51380  51400
# 2018-01-03  175448  177051  173045  174447   84790 -0.015819   52540  52560
# 2018-01-04  176048  179653  174847  178853  130112  0.025257   52120  52180
# 2018-01-05  178852  183858  176249  181857  136811  0.016796   51300  52120
# 2018-01-08  183258  190869  181856  190269  196338  0.046256   52400  52520
# ...            ...     ...     ...     ...     ...       ...     ...    ...
# 2019-12-23  185000  185500  182000  184000  250256  0.002725   56100  56400
# 2019-12-24  184000  184000  179000  182000  193440 -0.010870   55600  55700
# 2019-12-26  181500  183000  179000  180500  173426 -0.008242   54700  55400
# 2019-12-27  182000  185000  179000  183500  323473  0.016620   55700  56900
# ...

# %%
df = pd.concat([df_naver, df_samsung, lotte_che], keys=['naver', 'samsung', 'lotte'], names=['stock', '날짜'], axis=0, join='outer')
df
# Out:
#                              Open    High     Low   Close  Volume    Change  \
# stock 날짜
# naver 2016-01-04 00:00:00  130182  131784  126578  126579   93272 -0.039511
#       2016-01-05 00:00:00  126778  128580  126378  127580   69456  0.007908
#       2016-01-06 00:00:00  129181  129181  124575  124776   95682 -0.021978
#       2016-01-07 00:00:00  125377  132187  125377  130585  125253  0.046555
#       2016-01-08 00:00:00  130585  131987  128582  130585   63922  0.000000
# ...                           ...     ...     ...     ...     ...       ...
# lotte 2021-12-17           227000  235000  226500  234500  138945       NaN
#       2021-12-20           232000  233500  228000  229500   90630       NaN
#       2021-12-21           232000  232500  227000  229500   98669       NaN
#       2021-12-22           229000  230000  225000  225000   99419       NaN
#       2021-12-23                0       0       0       0       0       NaN
#
#                              Return
# ...

# %%
df = pd.concat([df_naver, df_samsung, lotte_che], keys=['naver', 'samsung', 'lotte'], names=['stock', '날짜'], axis=1, join='inner')
df
# Out:
# Empty DataFrame
# Columns: [(naver, Open), (naver, High), (naver, Low), (naver, Close), (naver, Volume), (naver, Change), (samsung, Open), (samsung, High), (samsung, Low), (samsung, Close), (samsung, Volume), (samsung, Change), (lotte, Open), (lotte, High), (lotte, Low), (lotte, Close), (lotte, Volume), (lotte, Return)]
# Index: []

# %%
df_naver.index
df_samsung.index
# Out:
# DatetimeIndex(['2018-01-02', '2018-01-03', '2018-01-04', '2018-01-05',
#                '2018-01-08', '2018-01-09', '2018-01-10', '2018-01-11',
#                '2018-01-12', '2018-01-15',
#                ...
#                '2020-12-16', '2020-12-17', '2020-12-18', '2020-12-21',
#                '2020-12-22', '2020-12-23', '2020-12-24', '2020-12-28',
#                '2020-12-29', '2020-12-30'],
#               dtype='datetime64[ns]', name='Date', length=738, freq=None)

# %%
lotte_che.index
# Out:
# Index(['2018-01-02', '2018-01-03', '2018-01-04', '2018-01-05', '2018-01-08',
#        '2018-01-09', '2018-01-10', '2018-01-11', '2018-01-12', '2018-01-15',
#        ...
#        '2021-12-10', '2021-12-13', '2021-12-14', '2021-12-15', '2021-12-16',
#        '2021-12-17', '2021-12-20', '2021-12-21', '2021-12-22', '2021-12-23'],
#       dtype='object', name='Date', length=981)

# %% [markdown]
# ### 합칠때 index가 같아야 한다 ( type까지 )

# %%
type(df_naver.index[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
type(lotte_che.index[0])
# Out:
# str

# %%
lotte_che.index = pd.to_datetime(lotte_che.index)
lotte_che.index
# Out:
# DatetimeIndex(['2018-01-02', '2018-01-03', '2018-01-04', '2018-01-05',
#                '2018-01-08', '2018-01-09', '2018-01-10', '2018-01-11',
#                '2018-01-12', '2018-01-15',
#                ...
#                '2021-12-10', '2021-12-13', '2021-12-14', '2021-12-15',
#                '2021-12-16', '2021-12-17', '2021-12-20', '2021-12-21',
#                '2021-12-22', '2021-12-23'],
#               dtype='datetime64[ns]', name='Date', length=981, freq=None)

# %%
df = pd.concat([df_naver, df_samsung, lotte_che], keys=['naver', 'samsung', 'lotte'], names=['stock', '날짜'], axis=1, join='inner')
df
# Out:
# stock        naver                                           samsung         \
# 날짜            Open    High     Low   Close  Volume    Change    Open   High
# Date
# 2018-01-02  174447  177251  174247  177251   93587  0.017240   51380  51400
# 2018-01-03  175448  177051  173045  174447   84790 -0.015819   52540  52560
# 2018-01-04  176048  179653  174847  178853  130112  0.025257   52120  52180
# 2018-01-05  178852  183858  176249  181857  136811  0.016796   51300  52120
# 2018-01-08  183258  190869  181856  190269  196338  0.046256   52400  52520
# ...            ...     ...     ...     ...     ...       ...     ...    ...
# 2019-12-23  185000  185500  182000  184000  250256  0.002725   56100  56400
# 2019-12-24  184000  184000  179000  182000  193440 -0.010870   55600  55700
# 2019-12-26  181500  183000  179000  180500  173426 -0.008242   54700  55400
# 2019-12-27  182000  185000  179000  183500  323473  0.016620   55700  56900
# ...

# %% [markdown]
# ## Nan 핸들링

# %% [markdown]
# ### Q) DataFrame 에서 Nan값에 해당되는 날짜만 찾는 방법은?

# %%
df_nan = pd.concat([df_naver, df_samsung, lotte_che], keys=['naver', 'samsung', 'lotte'], names=['stock', '날짜'], axis=1, join='outer')
df_nan
# Out:
# stock          naver                                                    \
# 날짜              Open      High       Low     Close    Volume    Change
# Date
# 2016-01-04  130182.0  131784.0  126578.0  126579.0   93272.0 -0.039511
# 2016-01-05  126778.0  128580.0  126378.0  127580.0   69456.0  0.007908
# 2016-01-06  129181.0  129181.0  124575.0  124776.0   95682.0 -0.021978
# 2016-01-07  125377.0  132187.0  125377.0  130585.0  125253.0  0.046555
# 2016-01-08  130585.0  131987.0  128582.0  130585.0   63922.0  0.000000
# ...              ...       ...       ...       ...       ...       ...
# 2021-12-17       NaN       NaN       NaN       NaN       NaN       NaN
# 2021-12-20       NaN       NaN       NaN       NaN       NaN       NaN
# 2021-12-21       NaN       NaN       NaN       NaN       NaN       NaN
# 2021-12-22       NaN       NaN       NaN       NaN       NaN       NaN
# 2021-12-23       NaN       NaN       NaN       NaN       NaN       NaN
#
# ...

# %%
df_nan['Close'] # 착각 Case1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Close'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df_nan[['Close']] # 착각 Case2
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2380\2240818260.py in <module>
# ----> 1 df_nan[['Close']] # 착각 Case2
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3509             if is_iterator(key):
#    3510                 key = list(key)
# -> 3511             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3512
#    3513         # take() does not accept boolean indexers
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\multi.py in _get_indexer_strict(self, key, axis_name)
#    2585             indexer = self._get_indexer_level_0(keyarr)
#    2586
# -> 2587             self._raise_if_missing(key, indexer, axis_name)
#    2588             return self[indexer], indexer
#    2589
#
# ...

# %%
df_nan[['Open','Close']] # 착각 Case3
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2380\4218321631.py in <module>
# ----> 1 df_nan[['Open','Close']] # 착각 Case3
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3509             if is_iterator(key):
#    3510                 key = list(key)
# -> 3511             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3512
#    3513         # take() does not accept boolean indexers
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\multi.py in _get_indexer_strict(self, key, axis_name)
#    2585             indexer = self._get_indexer_level_0(keyarr)
#    2586
# -> 2587             self._raise_if_missing(key, indexer, axis_name)
#    2588             return self[indexer], indexer
#    2589
#
# ...

# %%
df_nan.columns
# Out:
# MultiIndex([(  'naver',   'Open'),
#             (  'naver',   'High'),
#             (  'naver',    'Low'),
#             (  'naver',  'Close'),
#             (  'naver', 'Volume'),
#             (  'naver', 'Change'),
#             ('samsung',   'Open'),
#             ('samsung',   'High'),
#             ('samsung',    'Low'),
#             ('samsung',  'Close'),
#             ('samsung', 'Volume'),
#             ('samsung', 'Change'),
#             (  'lotte',   'Open'),
#             (  'lotte',   'High'),
#             (  'lotte',    'Low'),
#             (  'lotte',  'Close'),
#             (  'lotte', 'Volume'),
#             (  'lotte', 'Return')],
#            names=['stock', '날짜'])

# %%
df_nan[('samsung',  'Close')]
# Out:
# Date
# 2016-01-04   NaN
# 2016-01-05   NaN
# 2016-01-06   NaN
# 2016-01-07   NaN
# 2016-01-08   NaN
#               ..
# 2021-12-17   NaN
# 2021-12-20   NaN
# 2021-12-21   NaN
# 2021-12-22   NaN
# 2021-12-23   NaN
# Name: (samsung, Close), Length: 1470, dtype: float64

# %%
df_nan[[('samsung',  'Close')]]
# Out:
# stock      samsung
# 날짜           Close
# Date
# 2016-01-04     NaN
# 2016-01-05     NaN
# 2016-01-06     NaN
# 2016-01-07     NaN
# 2016-01-08     NaN
# ...            ...
# 2021-12-17     NaN
# 2021-12-20     NaN
# 2021-12-21     NaN
# 2021-12-22     NaN
# 2021-12-23     NaN
#
# [1470 rows x 1 columns]

# %%
df_samsung_close = df_nan[[('samsung',  'Close')]]
df_samsung_close
# Out:
# stock      samsung
# 날짜           Close
# Date
# 2016-01-04     NaN
# 2016-01-05     NaN
# 2016-01-06     NaN
# 2016-01-07     NaN
# 2016-01-08     NaN
# ...            ...
# 2021-12-17     NaN
# 2021-12-20     NaN
# 2021-12-21     NaN
# 2021-12-22     NaN
# 2021-12-23     NaN
#
# [1470 rows x 1 columns]

# %%
df_samsung_close.isna()
# Out:
# stock      samsung
# 날짜           Close
# Date
# 2016-01-04    True
# 2016-01-05    True
# 2016-01-06    True
# 2016-01-07    True
# 2016-01-08    True
# ...            ...
# 2021-12-17    True
# 2021-12-20    True
# 2021-12-21    True
# 2021-12-22    True
# 2021-12-23    True
#
# [1470 rows x 1 columns]

# %%
df_samsung_close.isna().sum()
# Out:
# stock    날짜
# samsung  Close    732
# dtype: int64

# %%
df_samsung_close.shape[0]
# Out:
# 1470

# %% [markdown]
# ### dropna로 join = 'inner' 효과 내기

# %%
df_nan
# Out:
# stock          naver                                                    \
# 날짜              Open      High       Low     Close    Volume    Change
# Date
# 2016-01-04  130182.0  131784.0  126578.0  126579.0   93272.0 -0.039511
# 2016-01-05  126778.0  128580.0  126378.0  127580.0   69456.0  0.007908
# 2016-01-06  129181.0  129181.0  124575.0  124776.0   95682.0 -0.021978
# 2016-01-07  125377.0  132187.0  125377.0  130585.0  125253.0  0.046555
# 2016-01-08  130585.0  131987.0  128582.0  130585.0   63922.0  0.000000
# ...              ...       ...       ...       ...       ...       ...
# 2021-12-17       NaN       NaN       NaN       NaN       NaN       NaN
# 2021-12-20       NaN       NaN       NaN       NaN       NaN       NaN
# 2021-12-21       NaN       NaN       NaN       NaN       NaN       NaN
# 2021-12-22       NaN       NaN       NaN       NaN       NaN       NaN
# 2021-12-23       NaN       NaN       NaN       NaN       NaN       NaN
#
# ...

# %%
df_nan.dropna()
# Out:
# stock          naver                                                    \
# 날짜              Open      High       Low     Close    Volume    Change
# Date
# 2018-01-02  174447.0  177251.0  174247.0  177251.0   93587.0  0.017240
# 2018-01-03  175448.0  177051.0  173045.0  174447.0   84790.0 -0.015819
# 2018-01-04  176048.0  179653.0  174847.0  178853.0  130112.0  0.025257
# 2018-01-05  178852.0  183858.0  176249.0  181857.0  136811.0  0.016796
# 2018-01-08  183258.0  190869.0  181856.0  190269.0  196338.0  0.046256
# ...              ...       ...       ...       ...       ...       ...
# 2019-12-23  185000.0  185500.0  182000.0  184000.0  250256.0  0.002725
# 2019-12-24  184000.0  184000.0  179000.0  182000.0  193440.0 -0.010870
# 2019-12-26  181500.0  183000.0  179000.0  180500.0  173426.0 -0.008242
# 2019-12-27  182000.0  185000.0  179000.0  183500.0  323473.0  0.016620
# 2019-12-30  183500.0  190000.0  183500.0  186500.0  376541.0  0.016349
#
# ...

# %% [markdown]
# #### dataFrame.dropna(axis=0) Delete row with Nan

# %%
df_nan.dropna(axis=0) # Nan 값이 존재하는 행 모두를 지운다.
# Out:
# stock          naver                                                    \
# 날짜              Open      High       Low     Close    Volume    Change
# Date
# 2018-01-02  174447.0  177251.0  174247.0  177251.0   93587.0  0.017240
# 2018-01-03  175448.0  177051.0  173045.0  174447.0   84790.0 -0.015819
# 2018-01-04  176048.0  179653.0  174847.0  178853.0  130112.0  0.025257
# 2018-01-05  178852.0  183858.0  176249.0  181857.0  136811.0  0.016796
# 2018-01-08  183258.0  190869.0  181856.0  190269.0  196338.0  0.046256
# ...              ...       ...       ...       ...       ...       ...
# 2019-12-23  185000.0  185500.0  182000.0  184000.0  250256.0  0.002725
# 2019-12-24  184000.0  184000.0  179000.0  182000.0  193440.0 -0.010870
# 2019-12-26  181500.0  183000.0  179000.0  180500.0  173426.0 -0.008242
# 2019-12-27  182000.0  185000.0  179000.0  183500.0  323473.0  0.016620
# 2019-12-30  183500.0  190000.0  183500.0  186500.0  376541.0  0.016349
#
# ...

# %% [markdown]
# #### dataFrame.dropna(axis=1) Delete Column With Nan

# %%
df_nan.dropna(axis=1) # Nan 값이 존재하는 모든 열을 지운다.
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
df_samsung_close.fillna(0)
# Out:
# stock      samsung
# 날짜           Close
# Date
# 2016-01-04     0.0
# 2016-01-05     0.0
# 2016-01-06     0.0
# 2016-01-07     0.0
# 2016-01-08     0.0
# ...            ...
# 2021-12-17     0.0
# 2021-12-20     0.0
# 2021-12-21     0.0
# 2021-12-22     0.0
# 2021-12-23     0.0
#
# [1470 rows x 1 columns]

# %%
df_samsung_close[df_samsung_close.isna()] # 이렇게 하면 될꺼 같은데...
# Out:
# stock      samsung
# 날짜           Close
# Date
# 2016-01-04     NaN
# 2016-01-05     NaN
# 2016-01-06     NaN
# 2016-01-07     NaN
# 2016-01-08     NaN
# ...            ...
# 2021-12-17     NaN
# 2021-12-20     NaN
# 2021-12-21     NaN
# 2021-12-22     NaN
# 2021-12-23     NaN
#
# [1470 rows x 1 columns]

# %%
df_samsung_close.isna()
# Out:
# stock      samsung
# 날짜           Close
# Date
# 2016-01-04    True
# 2016-01-05    True
# 2016-01-06    True
# 2016-01-07    True
# 2016-01-08    True
# ...            ...
# 2021-12-17    True
# 2021-12-20    True
# 2021-12-21    True
# 2021-12-22    True
# 2021-12-23    True
#
# [1470 rows x 1 columns]

# %%
df_samsung_close.isna().shape[0]
# Out:
# 1470

# %%
df_samsung_close.isna().values
# Out:
# array([[ True],
#        [ True],
#        [ True],
#        ...,
#        [ True],
#        [ True],
#        [ True]])

# %%
df_samsung_close.isna().values.shape[0]
# Out:
# 1470

# %%
df_samsung_close[df_samsung_close.isna().values]
# Out:
# stock      samsung
# 날짜           Close
# Date
# 2016-01-04     NaN
# 2016-01-05     NaN
# 2016-01-06     NaN
# 2016-01-07     NaN
# 2016-01-08     NaN
# ...            ...
# 2021-12-17     NaN
# 2021-12-20     NaN
# 2021-12-21     NaN
# 2021-12-22     NaN
# 2021-12-23     NaN
#
# [732 rows x 1 columns]

# %%
df_samsung_close[df_samsung_close.isna().values].index
# Out:
# DatetimeIndex(['2016-01-04', '2016-01-05', '2016-01-06', '2016-01-07',
#                '2016-01-08', '2016-01-11', '2016-01-12', '2016-01-13',
#                '2016-01-14', '2016-01-15',
#                ...
#                '2021-12-10', '2021-12-13', '2021-12-14', '2021-12-15',
#                '2021-12-16', '2021-12-17', '2021-12-20', '2021-12-21',
#                '2021-12-22', '2021-12-23'],
#               dtype='datetime64[ns]', name='Date', length=732, freq=None)

# %% [markdown]
# ## info(), describe()

# %%
import pandas as pd

df_samsung = pd.read_excel('samsung_naver_excel.xlsx', sheet_name = 'samsung', index_col = 0)

df_naver = pd.read_excel('samsung_naver_excel.xlsx', sheet_name = 'naver', index_col = 0)

df_lotte = pd.read_csv('롯데케미칼.csv', index_col = 0,header = 0)

df_lotte.index = pd.to_datetime(df_lotte.index)

df = pd.concat([df_naver, df_samsung, df_lotte], keys=['naver', 'samsung', 'lotte'], names=['stock', '날짜'], axis = 1, join = 'outer')
df
# Out:
# stock          naver                                                    \
# 날짜              Open      High       Low     Close    Volume    Change
# Date
# 2016-01-04  130182.0  131784.0  126578.0  126579.0   93272.0 -0.039511
# 2016-01-05  126778.0  128580.0  126378.0  127580.0   69456.0  0.007908
# 2016-01-06  129181.0  129181.0  124575.0  124776.0   95682.0 -0.021978
# 2016-01-07  125377.0  132187.0  125377.0  130585.0  125253.0  0.046555
# 2016-01-08  130585.0  131987.0  128582.0  130585.0   63922.0  0.000000
# ...              ...       ...       ...       ...       ...       ...
# 2021-12-16       NaN       NaN       NaN       NaN       NaN       NaN
# 2021-12-17       NaN       NaN       NaN       NaN       NaN       NaN
# 2021-12-20       NaN       NaN       NaN       NaN       NaN       NaN
# 2021-12-21       NaN       NaN       NaN       NaN       NaN       NaN
# 2021-12-22       NaN       NaN       NaN       NaN       NaN       NaN
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1469 entries, 2016-01-04 to 2021-12-22
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   (naver, Open)      979 non-null    float64
#  1   (naver, High)      979 non-null    float64
#  2   (naver, Low)       979 non-null    float64
#  3   (naver, Close)     979 non-null    float64
#  4   (naver, Volume)    979 non-null    float64
#  5   (naver, Change)    979 non-null    float64
#  6   (samsung, Open)    738 non-null    float64
#  7   (samsung, High)    738 non-null    float64
#  8   (samsung, Low)     738 non-null    float64
#  9   (samsung, Close)   738 non-null    float64
#  10  (samsung, Volume)  738 non-null    float64
#  11  (samsung, Change)  738 non-null    float64
#  12  (lotte, Open)      980 non-null    float64
#  13  (lotte, High)      980 non-null    float64
#  14  (lotte, Low)       980 non-null    float64
# ...

# %%
df.describe()
# Out:
# stock          naver                                               \
# 날짜              Open           High            Low          Close
# count     979.000000     979.000000     979.000000     979.000000
# mean   147904.304392  149774.075587  145962.802860  148274.173647
# std     20766.399720   20897.664784   20573.241066   19056.913614
# min         0.000000       0.000000       0.000000  106500.000000
# 25%    132544.000000  134500.000000  130441.500000  133000.000000
# 50%    151412.000000  153500.000000  149811.000000  151214.000000
# 75%    162230.000000  164000.000000  160426.500000  162029.000000
# max    189068.000000  195275.000000  186865.000000  192272.000000
#
# stock                                 samsung                              \
# 날짜           Volume      Change          Open          High           Low
# count  9.790000e+02  979.000000    738.000000    738.000000    738.000000
# mean   2.208698e+05    0.000545  50000.460705  50533.481030  49458.523035
# ...

# %% [markdown]
# ## 조건 (DataFrame과 DataFrame의 연산 주의!)

# %%
import pandas as pd
import numpy as np

df1 = pd.DataFrame({'a':[1,4,7], 'b':[2,5,8], 'c':[3,6,9]})
df1

df2 = pd.DataFrame({'a':[-1,-4,-7], 'b':[np.nan,np.nan,np.nan], 'e':[3,6,9]})
df2

df1 + df2 # Nan 연산시 Nan return, null 개념도 Nan
# Out:
#    a   b   c   e
# 0  0 NaN NaN NaN
# 1  0 NaN NaN NaN
# 2  0 NaN NaN NaN

# %% [markdown]
# DataFrame[Series조건값].index or values

# %%
pd.set_option('display.max_rows', 200)
#pd.set_option('display.max_rows', None)

df_samsung = pd.read_excel('samsung_kospi_excel.xlsx', sheet_name = 'samsung', index_col = 0)

df_kospi = pd.read_excel('samsung_kospi_excel.xlsx', sheet_name = 'kospi', index_col = 0)

df_kospi
# Out:
#               Close     Open     High      Low       Volume  Change
# Date
# 2016-01-04  1918.76  1954.47  1954.52  1918.76  359020000.0 -0.0217
# 2016-01-05  1930.53  1911.93  1937.57  1911.93  446550000.0  0.0061
# 2016-01-06  1925.43  1934.25  1934.25  1911.61  594610000.0 -0.0026
# 2016-01-07  1904.33  1915.71  1926.41  1901.24  393040000.0 -0.0110
# 2016-01-08  1917.62  1889.42  1918.25  1883.82  430200000.0  0.0070
# ...             ...      ...      ...      ...          ...     ...
# 2021-12-20  2963.00  3001.33  3001.33  2962.07  377580000.0 -0.0181
# 2021-12-21  2975.03  2981.67  2984.56  2955.90  410980000.0  0.0041
# 2021-12-22  2984.48  2993.50  3000.79  2976.65  461760000.0  0.0032
# 2021-12-23  2998.17  2998.02  3000.70  2980.91  483840000.0  0.0046
# 2021-12-24  3012.43  3009.48  3025.77  3009.48  537550000.0  0.0048
#
# [1471 rows x 6 columns]

# %% [markdown]
# ### DataFrame의 조건식에는 Series 값이 와야 한다.

# %%
df_kospi['Change']
# Out:
# Date
# 2016-01-04   -0.0217
# 2016-01-05    0.0061
# 2016-01-06   -0.0026
# 2016-01-07   -0.0110
# 2016-01-08    0.0070
#                ...
# 2021-12-20   -0.0181
# 2021-12-21    0.0041
# 2021-12-22    0.0032
# 2021-12-23    0.0046
# 2021-12-24    0.0048
# Name: Change, Length: 1471, dtype: float64

# %%
df_kospi['Change']>=0.01
# Out:
# Date
# 2016-01-04    False
# 2016-01-05    False
# 2016-01-06    False
# 2016-01-07    False
# 2016-01-08    False
#               ...
# 2021-12-20    False
# 2021-12-21    False
# 2021-12-22    False
# 2021-12-23    False
# 2021-12-24    False
# Name: Change, Length: 1471, dtype: bool

# %%
sum(df_kospi['Change']>=0.01)
# Out:
# 180

# %%
df_kospi[df_kospi['Change']>=0.01].index
# Out:
# DatetimeIndex(['2016-01-13', '2016-01-22', '2016-01-27', '2016-02-04',
#                '2016-02-15', '2016-02-16', '2016-02-18', '2016-03-02',
#                '2016-04-14', '2016-05-25',
#                ...
#                '2021-08-24', '2021-08-31', '2021-10-07', '2021-10-14',
#                '2021-11-02', '2021-11-12', '2021-11-15', '2021-11-22',
#                '2021-12-01', '2021-12-02'],
#               dtype='datetime64[ns]', name='Date', length=180, freq=None)

# %%
type(df_kospi['Change']>=0.01)
# Out:
# pandas.core.series.Series

# %% [markdown]
# ### Q) Kospi 상승이 1%가 넘는 날 삼성의 상승률을 구하여라

# %%
df_samsung[df_kospi['Change']>=0.01]
# Out:
#              Open   High    Low  Close    Volume    Change
# Date
# 2016-01-13  23060  23180  22960  22960    143316  0.001745
# 2016-01-22  22900  23360  22900  23360    147528  0.032714
# 2016-01-27  22520  23500  22520  23500    276237  0.033421
# 2016-02-04  23000  23220  22960  23120    247959  0.008726
# 2016-02-15  23080  23200  22880  23080    183146  0.021239
# 2016-02-16  23160  23580  23140  23360    180401  0.012132
# 2016-02-18  24060  24060  23560  23740    222481  0.001688
# 2016-03-02  24000  24140  23920  23940    236372  0.016129
# 2016-04-14  26000  26040  25780  26000    335327  0.019608
# 2016-05-25  25660  25960  25480  25900    237255  0.018883
# 2016-06-07  27720  28040  27600  27960    462843  0.015251
# 2016-06-20  28540  28960  28519  28620    270316  0.003506
# 2016-06-29  28160  28240  27820  27920    210541 -0.002144
# 2016-07-07  28420  29000  28320  29000    229904  0.020408
# 2016-07-11  29199  30000  29199  29780    281136  0.019863
# ...

# %%
df_samsung[df_kospi['Change']>=0.01]['Change']
# Out:
# Date
# 2016-01-13    0.001745
# 2016-01-22    0.032714
# 2016-01-27    0.033421
# 2016-02-04    0.008726
# 2016-02-15    0.021239
# 2016-02-16    0.012132
# 2016-02-18    0.001688
# 2016-03-02    0.016129
# 2016-04-14    0.019608
# 2016-05-25    0.018883
# 2016-06-07    0.015251
# 2016-06-20    0.003506
# 2016-06-29   -0.002144
# 2016-07-07    0.020408
# 2016-07-11    0.019863
# 2016-09-05    0.005636
# 2016-11-10    0.033208
# 2016-12-06    0.017462
# 2016-12-08    0.010158
# 2017-01-11    0.027927
# 2017-04-25    0.035403
# 2017-05-08    0.032953
# 2017-05-11   -0.002193
# 2017-05-25    0.017825
# 2017-06-02    0.028648
# 2017-09-07    0.023830
# 2017-09-18    0.041270
# 2017-10-10    0.029641
# 2017-10-11    0.034848
# 2017-11-01    0.038853
# 2017-12-04    0.009835
# 2017-12-28    0.032415
# 2018-01-05    0.020360
# 2018-01-23    0.019071
# 2018-02-14    0.030711
# 2018-02-23    0.009837
# 2018-03-06    0.040265
# 2018-03-08    0.011929
# 2018-03-09    0.010976
# ...

# %%
df_samsung[df_kospi['Change']>=0.01]['Change']*100
# Out:
# Date
# 2016-01-13     0.174520
# 2016-01-22     3.271441
# 2016-01-27     3.342128
# 2016-02-04     0.872600
# 2016-02-15     2.123894
# 2016-02-16     1.213172
# 2016-02-18     0.168776
# 2016-03-02     1.612903
# 2016-04-14     1.960784
# 2016-05-25     1.888277
# 2016-06-07     1.525054
# 2016-06-20     0.350631
# 2016-06-29    -0.214439
# 2016-07-07     2.040816
# 2016-07-11     1.986301
# 2016-09-05     0.563557
# 2016-11-10     3.320802
# 2016-12-06     1.746217
# 2016-12-08     1.015801
# 2017-01-11     2.792696
# 2017-04-25     3.540252
# 2017-05-08     3.295255
# 2017-05-11    -0.219298
# 2017-05-25     1.782531
# 2017-06-02     2.864816
# 2017-09-07     2.382979
# 2017-09-18     4.126984
# 2017-10-10     2.964119
# 2017-10-11     3.484848
# 2017-11-01     3.885258
# 2017-12-04     0.983478
# 2017-12-28     3.241491
# 2018-01-05     2.036022
# 2018-01-23     1.907131
# 2018-02-14     3.071098
# 2018-02-23     0.983747
# 2018-03-06     4.026549
# 2018-03-08     1.192925
# ...

# %% [markdown]
# ## Sorting

# %%
import pandas as pd

df_samsung = pd.read_excel('samsung_kospi_excel.xlsx', sheet_name = 'samsung', index_col = 0)

df_kospi = pd.read_excel('samsung_kospi_excel.xlsx', sheet_name = 'kospi', index_col = 0)

df_kospi
# Out:
#               Close     Open     High      Low       Volume  Change
# Date
# 2016-01-04  1918.76  1954.47  1954.52  1918.76  359020000.0 -0.0217
# 2016-01-05  1930.53  1911.93  1937.57  1911.93  446550000.0  0.0061
# 2016-01-06  1925.43  1934.25  1934.25  1911.61  594610000.0 -0.0026
# 2016-01-07  1904.33  1915.71  1926.41  1901.24  393040000.0 -0.0110
# 2016-01-08  1917.62  1889.42  1918.25  1883.82  430200000.0  0.0070
# ...             ...      ...      ...      ...          ...     ...
# 2021-12-20  2963.00  3001.33  3001.33  2962.07  377580000.0 -0.0181
# 2021-12-21  2975.03  2981.67  2984.56  2955.90  410980000.0  0.0041
# 2021-12-22  2984.48  2993.50  3000.79  2976.65  461760000.0  0.0032
# 2021-12-23  2998.17  2998.02  3000.70  2980.91  483840000.0  0.0046
# 2021-12-24  3012.43  3009.48  3025.77  3009.48  537550000.0  0.0048
#
# [1471 rows x 6 columns]

# %%
df = pd.DataFrame()

df['Kospi_Return'] = df_kospi['Change']

df['Samsung_Return'] = df_samsung['Change']

df = df * 100
df
# Out:
#             Kospi_Return  Samsung_Return
# Date
# 2016-01-04         -2.17       -4.365079
# 2016-01-05          0.61        0.248963
# 2016-01-06         -0.26       -2.731788
# 2016-01-07         -1.10       -1.021277
# 2016-01-08          0.70        0.687876
# ...                  ...             ...
# 2021-12-20         -1.81       -1.153846
# 2021-12-21          0.41        1.297017
# 2021-12-22          0.32        1.664533
# 2021-12-23          0.46        0.629723
# 2021-12-24          0.48        0.750939
#
# [1471 rows x 2 columns]

# %%
pd.set_option('display.max_rows', None)

# %% [markdown]
# ### Q) Kospi가 2% 상승한날 삼성전자도 2%이상 상승한 날을 구하시오

# %%
# Condition: Kospi가 2%상승한날과 삼성전자가 2%상승한날

df['Kospi_Return']>=2
df['Samsung_Return'] >=2
# Out:
# Date
# 2016-01-04    False
# 2016-01-05    False
# 2016-01-06    False
# 2016-01-07    False
# 2016-01-08    False
# 2016-01-11    False
# 2016-01-12    False
# 2016-01-13    False
# 2016-01-14    False
# 2016-01-15    False
# 2016-01-18    False
# 2016-01-19     True
# 2016-01-20    False
# 2016-01-21    False
# 2016-01-22     True
# 2016-01-25    False
# 2016-01-26    False
# 2016-01-27     True
# 2016-01-28    False
# 2016-01-29    False
# 2016-02-01    False
# 2016-02-02    False
# 2016-02-03    False
# 2016-02-04    False
# 2016-02-05    False
# 2016-02-11    False
# 2016-02-12    False
# 2016-02-15     True
# 2016-02-16    False
# 2016-02-17    False
# 2016-02-18    False
# 2016-02-19    False
# 2016-02-22    False
# 2016-02-23    False
# 2016-02-24    False
# 2016-02-25    False
# 2016-02-26    False
# 2016-02-29    False
# 2016-03-02    False
# 2016-03-03    False
# 2016-03-04    False
# 2016-03-07    False
# 2016-03-08    False
# 2016-03-09    False
# 2016-03-10     True
# ...

# %%
(df['Kospi_Return'] >=2) & (df['Samsung_Return']>=2)
# Out:
# Date
# 2016-01-04    False
# 2016-01-05    False
# 2016-01-06    False
# 2016-01-07    False
# 2016-01-08    False
# 2016-01-11    False
# 2016-01-12    False
# 2016-01-13    False
# 2016-01-14    False
# 2016-01-15    False
# 2016-01-18    False
# 2016-01-19    False
# 2016-01-20    False
# 2016-01-21    False
# 2016-01-22     True
# 2016-01-25    False
# 2016-01-26    False
# 2016-01-27    False
# 2016-01-28    False
# 2016-01-29    False
# 2016-02-01    False
# 2016-02-02    False
# 2016-02-03    False
# 2016-02-04    False
# 2016-02-05    False
# 2016-02-11    False
# 2016-02-12    False
# 2016-02-15    False
# 2016-02-16    False
# 2016-02-17    False
# 2016-02-18    False
# 2016-02-19    False
# 2016-02-22    False
# 2016-02-23    False
# 2016-02-24    False
# 2016-02-25    False
# 2016-02-26    False
# 2016-02-29    False
# 2016-03-02    False
# 2016-03-03    False
# 2016-03-04    False
# 2016-03-07    False
# 2016-03-08    False
# 2016-03-09    False
# 2016-03-10    False
# ...

# %%
df['Condition'] = np.where(((df['Kospi_Return'] >=2) & (df['Samsung_Return']>=2)), df['Samsung_Return'], np.nan)
df['Condition'] # 조건에 해당하는 series 생성
# Out:
# Date
# 2016-01-04          NaN
# 2016-01-05          NaN
# 2016-01-06          NaN
# 2016-01-07          NaN
# 2016-01-08          NaN
# 2016-01-11          NaN
# 2016-01-12          NaN
# 2016-01-13          NaN
# 2016-01-14          NaN
# 2016-01-15          NaN
# 2016-01-18          NaN
# 2016-01-19          NaN
# 2016-01-20          NaN
# 2016-01-21          NaN
# 2016-01-22     3.271441
# 2016-01-25          NaN
# 2016-01-26          NaN
# 2016-01-27          NaN
# 2016-01-28          NaN
# 2016-01-29          NaN
# 2016-02-01          NaN
# 2016-02-02          NaN
# 2016-02-03          NaN
# 2016-02-04          NaN
# 2016-02-05          NaN
# 2016-02-11          NaN
# 2016-02-12          NaN
# 2016-02-15          NaN
# 2016-02-16          NaN
# 2016-02-17          NaN
# 2016-02-18          NaN
# 2016-02-19          NaN
# 2016-02-22          NaN
# 2016-02-23          NaN
# 2016-02-24          NaN
# 2016-02-25          NaN
# 2016-02-26          NaN
# 2016-02-29          NaN
# ...

# %%
df_result = df.dropna()

df_result
# Out:
#             Kospi_Return  Samsung_Return  Condition
# Date
# 2016-01-22          2.11        3.271441   3.271441
# 2016-11-10          2.26        3.320802   3.320802
# 2017-05-08          2.30        3.295255   3.295255
# 2018-11-02          3.53        4.744958   4.744958
# 2020-02-06          2.88        2.689076   2.689076
# 2020-03-04          2.24        3.610108   3.610108
# 2020-03-20          7.44        5.704307   5.704307
# 2020-03-24          8.60       10.470588  10.470588
# 2020-03-25          5.89        3.620873   3.620873
# 2020-04-02          2.34        2.183406   2.183406
# 2020-04-06          3.85        3.617021   3.617021
# 2020-04-17          3.09        4.897959   4.897959
# 2020-05-19          2.25        3.073770   3.073770
# 2020-06-03          2.87        6.031128   6.031128
# 2020-06-16          5.28        4.408818   4.408818
# 2020-11-05          2.40        3.076923   3.076923
# 2020-12-09          2.02        3.068340   3.068340
# ...

# %% [markdown]
# ### df.sort_index(ascending = True/False) 날짜(기본 인덱스) 순으로 보기

# %%
# index _ Sorting

df_result.sort_index(ascending = False)
# Out:
#             Kospi_Return  Samsung_Return  Condition
# Date
# 2021-12-01          2.14        4.347826   4.347826
# 2021-02-25          3.50        4.024390   4.024390
# 2021-01-25          2.18        2.995392   2.995392
# 2021-01-19          2.61        2.352941   2.352941
# 2021-01-08          3.97        7.117008   7.117008
# 2021-01-04          2.47        2.469136   2.469136
# 2020-12-09          2.02        3.068340   3.068340
# 2020-11-05          2.40        3.076923   3.076923
# 2020-06-16          5.28        4.408818   4.408818
# 2020-06-03          2.87        6.031128   6.031128
# 2020-05-19          2.25        3.073770   3.073770
# 2020-04-17          3.09        4.897959   4.897959
# 2020-04-06          3.85        3.617021   3.617021
# 2020-04-02          2.34        2.183406   2.183406
# 2020-03-25          5.89        3.620873   3.620873
# 2020-03-24          8.60       10.470588  10.470588
# 2020-03-20          7.44        5.704307   5.704307
# ...

# %% [markdown]
# ### df.sort_values(by = '열명', ascending = True/False)상승률 순으로 보기

# %%
# Value _ Sorting

df_result.sort_values(by = 'Kospi_Return', ascending = True)

# %% [markdown]
# ## reset_index & drop

# %%
df_samsung = pd.read_excel('samsung_kospi_excel.xlsx', sheet_name = 'samsung', index_col = 0)

df_kospi = pd.read_excel('samsung_kospi_excel.xlsx', sheet_name = 'kospi', index_col = 0)

df['Condition'] = np.where(((df['Kospi_Return'] >=2) & (df['Samsung_Return']>=2)), df['Samsung_Return'], np.nan)
df
# Out:
#             Kospi_Return  Samsung_Return  Condition
# Date
# 2016-01-04         -2.17       -4.365079        NaN
# 2016-01-05          0.61        0.248963        NaN
# 2016-01-06         -0.26       -2.731788        NaN
# 2016-01-07         -1.10       -1.021277        NaN
# 2016-01-08          0.70        0.687876        NaN
# 2016-01-11         -1.19       -1.622545        NaN
# 2016-01-12         -0.21       -0.520833        NaN
# 2016-01-13          1.34        0.174520        NaN
# 2016-01-14         -0.85       -0.871080        NaN
# 2016-01-15         -1.11       -0.527241        NaN
# 2016-01-18         -0.02       -0.530035        NaN
# 2016-01-19          0.60        3.996448        NaN
# 2016-01-20         -2.34       -2.818104        NaN
# 2016-01-21         -0.27       -0.615114        NaN
# 2016-01-22          2.11        3.271441   3.271441
# 2016-01-25          0.74       -0.513699        NaN
# 2016-01-26         -1.15       -2.151463        NaN
# ...

# %%
df_result = df.dropna() # Nan을 날린다

df_result
# Out:
#             Kospi_Return  Samsung_Return  Condition
# Date
# 2016-01-22          2.11        3.271441   3.271441
# 2016-11-10          2.26        3.320802   3.320802
# 2017-05-08          2.30        3.295255   3.295255
# 2018-11-02          3.53        4.744958   4.744958
# 2020-02-06          2.88        2.689076   2.689076
# 2020-03-04          2.24        3.610108   3.610108
# 2020-03-20          7.44        5.704307   5.704307
# 2020-03-24          8.60       10.470588  10.470588
# 2020-03-25          5.89        3.620873   3.620873
# 2020-04-02          2.34        2.183406   2.183406
# 2020-04-06          3.85        3.617021   3.617021
# 2020-04-17          3.09        4.897959   4.897959
# 2020-05-19          2.25        3.073770   3.073770
# 2020-06-03          2.87        6.031128   6.031128
# 2020-06-16          5.28        4.408818   4.408818
# 2020-11-05          2.40        3.076923   3.076923
# 2020-12-09          2.02        3.068340   3.068340
# ...

# %% [markdown]
# dataFrame.reset_index() 데이터를 원하는 형태로 가공할때 기존에 사용하던 index를 사용하지 않고 새로운 index를 만들어 데이터를 넣거나 빼 새로 가공한다

# %%
df_reset = df_result.reset_index()
df_reset
# Out:
#          Date  Kospi_Return  Samsung_Return  Condition
# 0  2016-01-22          2.11        3.271441   3.271441
# 1  2016-11-10          2.26        3.320802   3.320802
# 2  2017-05-08          2.30        3.295255   3.295255
# 3  2018-11-02          3.53        4.744958   4.744958
# 4  2020-02-06          2.88        2.689076   2.689076
# 5  2020-03-04          2.24        3.610108   3.610108
# 6  2020-03-20          7.44        5.704307   5.704307
# 7  2020-03-24          8.60       10.470588  10.470588
# 8  2020-03-25          5.89        3.620873   3.620873
# 9  2020-04-02          2.34        2.183406   2.183406
# 10 2020-04-06          3.85        3.617021   3.617021
# 11 2020-04-17          3.09        4.897959   4.897959
# 12 2020-05-19          2.25        3.073770   3.073770
# 13 2020-06-03          2.87        6.031128   6.031128
# 14 2020-06-16          5.28        4.408818   4.408818
# 15 2020-11-05          2.40        3.076923   3.076923
# ...

# %% [markdown]
# ### dataFrame.drop('열이름', axis=1)

# %%
# drop
df_reset.drop(['Date','Kospi_Return','Samsung_Return'], axis = 1) # 필요없는 'Date','Kospi_Return','Samsung_Return'컬럼을 날린다

# %% [markdown]
# ### dataFrame.drop('행값', axis=0)

# %%
df_reset.drop(6, axis = 0)
# Out:
#          Date  Kospi_Return  Samsung_Return  Condition
# 0  2016-01-22          2.11        3.271441   3.271441
# 1  2016-11-10          2.26        3.320802   3.320802
# 2  2017-05-08          2.30        3.295255   3.295255
# 3  2018-11-02          3.53        4.744958   4.744958
# 4  2020-02-06          2.88        2.689076   2.689076
# 5  2020-03-04          2.24        3.610108   3.610108
# 7  2020-03-24          8.60       10.470588  10.470588
# 8  2020-03-25          5.89        3.620873   3.620873
# 9  2020-04-02          2.34        2.183406   2.183406
# 10 2020-04-06          3.85        3.617021   3.617021
# 11 2020-04-17          3.09        4.897959   4.897959
# 12 2020-05-19          2.25        3.073770   3.073770
# 13 2020-06-03          2.87        6.031128   6.031128
# 14 2020-06-16          5.28        4.408818   4.408818
# 15 2020-11-05          2.40        3.076923   3.076923
# 16 2020-12-09          2.02        3.068340   3.068340
# ...

# %% [markdown]
# df_reset.drop(['Date','Kospi_Return','Samsung_Return'], axis = 1)
# 와
# df_reset = df_reset.drop(['Date','Kospi_Return','Samsung_Return'], axis = 1)
# 차이
#
# 전자는 df_reset을 그대로 가지고 있고
# 후자는 수정된 데이터가 저장된다.

# %% [markdown]
# ## Count

# %%
pd.set_option('display.max_rows', 200)

# %%
import pandas as pd

#pd.set_option('display.max_rows', None)

krx = pd.read_csv("KRX.csv") # 인코딩 에러...
krx
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2380\1244379690.py in <module>
#       3 #pd.set_option('display.max_rows', None)
#       4
# ----> 5 krx = pd.read_csv("KRX.csv")
#       6 krx
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
krx = pd.read_csv("KRX.csv", encoding = 'cp949')
krx
# Out:
#       Unnamed: 0  Symbol  Market     Name                    Sector  \
# 0              0   60310  KOSDAQ       3S                  전자부품 제조업
# 1              1   95570   KOSPI   AJ네트웍스           산업용 기계 및 장비 임대업
# 2              2    6840   KOSPI    AK홀딩스                    기타 금융업
# 3              3   54620  KOSDAQ   APS홀딩스                    기타 금융업
# 4              4  265520  KOSDAQ    AP시스템             특수 목적용 기계 제조업
# ...          ...     ...     ...      ...                       ...
# 7296        7296     547   KOSPI  흥국화재2우B                       NaN
# 7297        7297     545   KOSPI    흥국화재우                       NaN
# 7298        7298    3280   KOSPI     흥아해운                    해상 운송업
# 7299        7299   37440  KOSDAQ       희림  건축기술, 엔지니어링 및 관련 기술 서비스업
# 7300        7300  238490  KOSDAQ       힘스             특수 목적용 기계 제조업
#
#                             Industry ListingDate SettleMonth  \
# 0                        반도체 웨이퍼 캐리어  2002-04-23         03월
# ...

# %%
krx = pd.read_csv("KRX.csv", encoding = 'cp949', index_col = 0)
krx
# Out:
#       Symbol  Market     Name                    Sector  \
# 0      60310  KOSDAQ       3S                  전자부품 제조업
# 1      95570   KOSPI   AJ네트웍스           산업용 기계 및 장비 임대업
# 2       6840   KOSPI    AK홀딩스                    기타 금융업
# 3      54620  KOSDAQ   APS홀딩스                    기타 금융업
# 4     265520  KOSDAQ    AP시스템             특수 목적용 기계 제조업
# ...      ...     ...      ...                       ...
# 7296     547   KOSPI  흥국화재2우B                       NaN
# 7297     545   KOSPI    흥국화재우                       NaN
# 7298    3280   KOSPI     흥아해운                    해상 운송업
# 7299   37440  KOSDAQ       희림  건축기술, 엔지니어링 및 관련 기술 서비스업
# 7300  238490  KOSDAQ       힘스             특수 목적용 기계 제조업
#
#                             Industry ListingDate SettleMonth  \
# 0                        반도체 웨이퍼 캐리어  2002-04-23         03월
# 1                렌탈(파렛트, OA장비, 건설장비)  2015-08-21         12월
# 2                               지주사업  1999-08-11         12월
# ...

# %% [markdown]
# ### unique()

# %%
krx['Sector']
# Out:
# 0                       전자부품 제조업
# 1                산업용 기계 및 장비 임대업
# 2                         기타 금융업
# 3                         기타 금융업
# 4                  특수 목적용 기계 제조업
#                   ...
# 7296                         NaN
# 7297                         NaN
# 7298                      해상 운송업
# 7299    건축기술, 엔지니어링 및 관련 기술 서비스업
# 7300               특수 목적용 기계 제조업
# Name: Sector, Length: 7301, dtype: object

# %%
krx['Sector'].unique()
# Out:
# array(['전자부품 제조업', '산업용 기계 및 장비 임대업', '기타 금융업', '특수 목적용 기계 제조업',
#        '통신 및 방송 장비 제조업', nan, '종합 소매업', '기계장비 및 관련 물품 도매업', '봉제의복 제조업',
#        '자동차 신품 부품 제조업', '영화, 비디오물, 방송프로그램 제작 및 배급업', '텔레비전 방송업',
#        '도로 화물 운송업', '기타 식품 제조업', '음·식료품 및 담배 도매업', '의약품 제조업',
#        '신탁업 및 집합투자업', '기타 전문 도매업', '소프트웨어 개발 및 공급업', '기타 화학제품 제조업',
#        '컴퓨터 프로그래밍, 시스템 통합 및 관리업', '금융 지원 서비스업', '보험업', '반도체 제조업',
#        '상품 중개업', '건물 건설업', '토목 건설업', '고무제품 제조업', '1차 비철금속 제조업',
#        '1차 철강 제조업', '자연과학 및 공학 연구개발업',
#        '전동기, 발전기 및 전기 변환 · 공급 · 제어 장치 제조업', '부동산 임대 및 공급업', '생활용품 도매업',
#        '기타 섬유제품 제조업', '유원지 및 기타 오락관련 서비스업', '상품 종합 도매업', '전기 및 통신 공사업',
#        '해상 운송업', '합성고무 및 플라스틱 물질 제조업', '일반 목적용 기계 제조업', '영상 및 음향기기 제조업',
#        '오디오물 출판 및 원판 녹음업', '유리 및 유리제품 제조업', '시멘트, 석회, 플라스터 및 그 제품 제조업',
#        '폐기물 처리업', '기초 화학물질 제조업', '플라스틱제품 제조업', '기초 의약물질 및 생물학적 제제 제조업',
#        '그외 기타 운송장비 제조업', '전기 통신업', '담배 제조업', '기타 정보 서비스업', '무기 및 총포탄 제조업',
# ...

# %%
type(krx['Sector'].unique())
# Out:
# numpy.ndarray

# %%
krx['Sector'].unique().shape[0]
# Out:
# 162

# %%
krx['Sector'].count()
# Out:
# 2487

# %%
krx.count()
# Out:
# Symbol            7301
# Market            7301
# Name              7301
# Sector            2487
# Industry          2468
# ListingDate       2487
# SettleMonth       2487
# Representative    2487
# HomePage          2339
# Region            2487
# Unnamed: 11          1
# dtype: int64

# %% [markdown]
# ### KRX에 상장된 섹터 중 가장 많이상장된 섹터는?

# %%
krx['Sector'].value_count()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2380\1005849138.py in <module>
# ----> 1 krx['Sector'].value_count()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'value_count'

# %%
krx.value_counts()
# Out:
# Symbol  Market  Name   Sector         Industry                ListingDate  SettleMonth  Representative  HomePage  Region                        Unnamed: 11
# 241790  KOSDAQ  오션브릿지  특수 목적용 기계 제조업  반도체 케미칼 및 특수가스, 반도체 장비  2016-12-01   12월          이석규             http://   http://www.oceanbridge.co.kr  경기도            1
# dtype: int64

# %% [markdown]
# ### value_counts() 원하는 섹터의 개수

# %%
krx['Sector'].value_counts()
# Out:
# 소프트웨어 개발 및 공급업                           152
# 특수 목적용 기계 제조업                            143
# 전자부품 제조업                                 128
# 자동차 신품 부품 제조업                             96
# 의약품 제조업                                   95
# 기타 화학제품 제조업                               94
# 기타 금융업                                    92
# 금융 지원 서비스업                                74
# 통신 및 방송 장비 제조업                            72
# 자연과학 및 공학 연구개발업                           59
# 반도체 제조업                                   58
# 1차 철강 제조업                                 57
# 의료용 기기 제조업                                56
# 일반 목적용 기계 제조업                             45
# 플라스틱제품 제조업                                44
# 기초 화학물질 제조업                               43
# 기초 의약물질 및 생물학적 제제 제조업                     39
# 기타 전문 도매업                                 38
# 컴퓨터 프로그래밍, 시스템 통합 및 관리업                   37
# 전동기, 발전기 및 전기 변환 · 공급 · 제어 장치 제조업         35
# 기타 식품 제조업                                 34
# ...

# %%
krx['Sector'].value_counts().sort_values(ascending = True)
# Out:
# 해체, 선별 및 원료 재생업                            1
# 환경 정화 및 복원업                                1
# 건축자재, 철물 및 난방장치 도매업                        1
# 편조원단 제조업                                   1
# 신발 및 신발 부분품 제조업                            1
# 증기, 냉·온수 및 공기조절 공급업                        1
# 재 보험업                                      1
# 그외 기타 개인 서비스업                              1
# 개인 및 가정용품 임대업                              1
# 음·식료품 및 담배 소매업                             1
# 철도장비 제조업                                   1
# 기타 비금속광물 광업                                1
# 악기 제조업                                     1
# 기타 생활용품 소매업                                1
# 의복 액세서리 제조업                                1
# 편조의복 제조업                                   1
# 자동차 재제조 부품 제조업                             1
# 담배 제조업                                     1
# 운동 및 경기용구 제조업                              1
# 인형,장난감 및 오락용품 제조업                          1
# 기타 전문 서비스업                                 1
# ...

# %% [markdown]
# #### 해당 섹터에 대한 상세 정보를 확인해 보자

# %%
krx['Sector'] == "석유 정제품 제조업"
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7296    False
# 7297    False
# 7298    False
# 7299    False
# 7300    False
# Name: Sector, Length: 7301, dtype: bool

# %%
krx[krx['Sector'] == "석유 정제품 제조업"]
# Out:
#       Symbol Market     Name      Sector  \
# 1892   10950  KOSPI    S-Oil  석유 정제품 제조업
# 1933   96770  KOSPI  SK이노베이션  석유 정제품 제조업
# 2232   14530  KOSPI     극동유화  석유 정제품 제조업
# 3936    3650  KOSPI     미창석유  석유 정제품 제조업
# 7059    2960  KOSPI    한국쉘석유  석유 정제품 제조업
# 7226  267250  KOSPI  현대중공업지주  석유 정제품 제조업
#
#                                                Industry ListingDate  \
# 1892                  석유제품,가스,윤활기유,윤활유,그리스,석유화학제품 제조,도매  1987-05-27
# 1933  석유정제,석유화학제품,윤활유제품,아스팔트제품,의약중간체 제조,판매,유전개발,대체에너지사업  2007-07-25
# 2232  윤활유,유동파라핀,왁스,방수용시트,아스팔트 제조/수입자동차,부품 도매/가스충전,산업...  1991-01-31
# 3936                          윤활유,고무배합유,전기절연유 제조,판매,수출입  1989-09-27
# 7059                                      윤활유,그리스 제조,도매  1988-08-10
# 7226                                               지주회사  2017-05-10
#
#      SettleMonth        Representative                           HomePage  \
# 1892         12월  Hussain A.Al-Qahtani               http://www.s-oil.com
# ...

# %%
krx[krx['Sector'] == "석유 정제품 제조업"].count()
# Out:
# Symbol            6
# Market            6
# Name              6
# Sector            6
# Industry          6
# ListingDate       6
# SettleMonth       6
# Representative    6
# HomePage          6
# Region            6
# Unnamed: 11       0
# dtype: int64

# %%
krx[krx['Sector'] == "석유 정제품 제조업"].count().info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 11 entries, Symbol to Unnamed: 11
# Series name: None
# Non-Null Count  Dtype
# --------------  -----
# 11 non-null     int64
# dtypes: int64(1)
# memory usage: 476.0+ bytes

# %% [markdown]
# ## GroupBy

# %%
import pandas as pd

# %% [markdown]
# ### Data를 원하는 형태로 가공하기 ( dropna 사용 )

# %% [markdown]
# 참조하는 자료가 Parsing 하기에 깔끔한 자료가 아닐 수 있다.
# 필요한 자료 영역의 헤더를 찾고 나머지를 정리하는 작업을 수행 해 본다.

# %%
df = pd.read_excel('groupby_example.xlsx')
df
# Out:
#     Sector   반도체      통신   화학  플랫폼  바이오
# 0      NaN   NaN     NaN  NaN  NaN  NaN
# 1      NaN   NaN     NaN  NaN  NaN  NaN
# 2      NaN   NaN     NaN  NaN  NaN  NaN
# 3      NaN   NaN     NaN  NaN  NaN  NaN
# 4      NaN   NaN     NaN  NaN  NaN  NaN
# 5      NaN   NaN  Sector  PER  NaN  NaN
# 6      NaN   기업1     반도체  1.5  NaN  NaN
# 7      NaN   기업2      통신  1.1  NaN  NaN
# 8      NaN   기업3      화학  0.5  NaN  NaN
# 9      NaN   기업4     플랫폼    3  NaN  NaN
# 10     NaN   기업5     바이오   10  NaN  NaN
# 11     NaN   기업6      통신  1.6  NaN  NaN
# 12     NaN   기업7      화학  0.7  NaN  NaN
# 13     NaN   기업8     바이오   15  NaN  NaN
# 14     NaN   기업9     반도체    2  NaN  NaN
# 15     NaN  기업10      통신  1.6  NaN  NaN
# 16     NaN  기업11      화학  0.7  NaN  NaN
# 17     NaN  기업12     플랫폼    4  NaN  NaN
# 18     NaN  기업13     바이오    2  NaN  NaN
# 19     NaN  기업14     바이오   10  NaN  NaN
# 20     NaN  기업15      통신  1.6  NaN  NaN
# 21     NaN  기업16     반도체  0.9  NaN  NaN
# ...

# %%
df = pd.read_excel('groupby_example.xlsx', header = 6, usecols=[2,3,4]) # header가 될 인덱스 찾아주고..
df 
# usecols에서 [1] 뺀 이유
# dropna(axis = 0)에서 header Nan 값도 날려 버리기 때문에
# Out:
#    Sector   PER   ex
# 0     반도체   1.5  1.0
# 1      통신   1.1  1.0
# 2      화학   0.5  NaN
# 3     플랫폼   3.0  NaN
# 4     바이오  10.0  NaN
# 5      통신   1.6  NaN
# 6      화학   0.7  NaN
# 7     바이오  15.0  NaN
# 8     반도체   2.0  NaN
# 9      통신   1.6  NaN
# 10     화학   0.7  NaN
# 11    플랫폼   4.0  NaN
# 12    바이오   2.0  NaN
# 13    바이오  10.0  NaN
# 14     통신   1.6  NaN
# 15    반도체   0.9  NaN
# 16    반도체   2.1  NaN
# 17    플랫폼   2.5  NaN
# 18     화학   1.1  NaN
# 19     화학   0.4  NaN
# 20    반도체   1.6  NaN
# 21    플랫폼   4.2  NaN
# 22     통신   1.3  NaN
# 23     화학   0.6  NaN
# 24    바이오  12.0  NaN

# %%
df.dropna(axis = 0)
# Out:
#   Sector  PER   ex
# 0    반도체  1.5  1.0
# 1     통신  1.1  1.0

# %%
df = df.dropna(axis = 1)
df
# Out:
#    Sector   PER
# 0     반도체   1.5
# 1      통신   1.1
# 2      화학   0.5
# 3     플랫폼   3.0
# 4     바이오  10.0
# 5      통신   1.6
# 6      화학   0.7
# 7     바이오  15.0
# 8     반도체   2.0
# 9      통신   1.6
# 10     화학   0.7
# 11    플랫폼   4.0
# 12    바이오   2.0
# 13    바이오  10.0
# 14     통신   1.6
# 15    반도체   0.9
# 16    반도체   2.1
# 17    플랫폼   2.5
# 18     화학   1.1
# 19     화학   0.4
# 20    반도체   1.6
# 21    플랫폼   4.2
# 22     통신   1.3
# 23     화학   0.6
# 24    바이오  12.0

# %%
df = pd.read_excel('groupby_example.xlsx', header = 6) 
df
# Out:
#     Unnamed: 0 Unnamed: 1 Sector   PER   ex  Unnamed: 5
# 0          NaN        기업1    반도체   1.5  1.0         NaN
# 1          NaN        기업2     통신   1.1  1.0         NaN
# 2          NaN        기업3     화학   0.5  NaN         NaN
# 3          NaN        기업4    플랫폼   3.0  NaN         NaN
# 4          NaN        기업5    바이오  10.0  NaN         NaN
# 5          NaN        기업6     통신   1.6  NaN         NaN
# 6          NaN        기업7     화학   0.7  NaN         NaN
# 7          NaN        기업8    바이오  15.0  NaN         NaN
# 8          NaN        기업9    반도체   2.0  NaN         NaN
# 9          NaN       기업10     통신   1.6  NaN         NaN
# 10         NaN       기업11     화학   0.7  NaN         NaN
# 11         NaN       기업12    플랫폼   4.0  NaN         NaN
# 12         NaN       기업13    바이오   2.0  NaN         NaN
# 13         NaN       기업14    바이오  10.0  NaN         NaN
# 14         NaN       기업15     통신   1.6  NaN         NaN
# 15         NaN       기업16    반도체   0.9  NaN         NaN
# ...

# %% [markdown]
# #### 필요 없는 열 제거

# %%
df = df.dropna(axis = 1)
df
# Out:
#    Unnamed: 1 Sector   PER
# 0         기업1    반도체   1.5
# 1         기업2     통신   1.1
# 2         기업3     화학   0.5
# 3         기업4    플랫폼   3.0
# 4         기업5    바이오  10.0
# 5         기업6     통신   1.6
# 6         기업7     화학   0.7
# 7         기업8    바이오  15.0
# 8         기업9    반도체   2.0
# 9        기업10     통신   1.6
# 10       기업11     화학   0.7
# 11       기업12    플랫폼   4.0
# 12       기업13    바이오   2.0
# 13       기업14    바이오  10.0
# 14       기업15     통신   1.6
# 15       기업16    반도체   0.9
# 16       기업17    반도체   2.1
# 17       기업18    플랫폼   2.5
# 18       기업19     화학   1.1
# 19       기업20     화학   0.4
# 20       기업21    반도체   1.6
# 21       기업22    플랫폼   4.2
# 22       기업23     통신   1.3
# 23       기업24     화학   0.6
# 24       기업25    바이오  12.0

# %% [markdown]
# #### '기업' 열을 인덱스로 만드는 방법

# %%
df.columns = ['기업', 'Sector', 'PER']
df
# Out:
#       기업 Sector   PER
# 0    기업1    반도체   1.5
# 1    기업2     통신   1.1
# 2    기업3     화학   0.5
# 3    기업4    플랫폼   3.0
# 4    기업5    바이오  10.0
# 5    기업6     통신   1.6
# 6    기업7     화학   0.7
# 7    기업8    바이오  15.0
# 8    기업9    반도체   2.0
# 9   기업10     통신   1.6
# 10  기업11     화학   0.7
# 11  기업12    플랫폼   4.0
# 12  기업13    바이오   2.0
# 13  기업14    바이오  10.0
# 14  기업15     통신   1.6
# 15  기업16    반도체   0.9
# 16  기업17    반도체   2.1
# 17  기업18    플랫폼   2.5
# 18  기업19     화학   1.1
# 19  기업20     화학   0.4
# 20  기업21    반도체   1.6
# 21  기업22    플랫폼   4.2
# 22  기업23     통신   1.3
# 23  기업24     화학   0.6
# 24  기업25    바이오  12.0

# %%
df.index = df['기업']
df
# Out:
#         기업 Sector   PER
# 기업
# 기업1    기업1    반도체   1.5
# 기업2    기업2     통신   1.1
# 기업3    기업3     화학   0.5
# 기업4    기업4    플랫폼   3.0
# 기업5    기업5    바이오  10.0
# 기업6    기업6     통신   1.6
# 기업7    기업7     화학   0.7
# 기업8    기업8    바이오  15.0
# 기업9    기업9    반도체   2.0
# 기업10  기업10     통신   1.6
# 기업11  기업11     화학   0.7
# 기업12  기업12    플랫폼   4.0
# 기업13  기업13    바이오   2.0
# 기업14  기업14    바이오  10.0
# 기업15  기업15     통신   1.6
# 기업16  기업16    반도체   0.9
# 기업17  기업17    반도체   2.1
# 기업18  기업18    플랫폼   2.5
# 기업19  기업19     화학   1.1
# 기업20  기업20     화학   0.4
# 기업21  기업21    반도체   1.6
# 기업22  기업22    플랫폼   4.2
# 기업23  기업23     통신   1.3
# 기업24  기업24     화학   0.6
# 기업25  기업25    바이오  12.0

# %%
df = df.drop('기업', axis = 1) # 기업 column의 열 제거
df
# Out:
#      Sector   PER
# 기업
# 기업1     반도체   1.5
# 기업2      통신   1.1
# 기업3      화학   0.5
# 기업4     플랫폼   3.0
# 기업5     바이오  10.0
# 기업6      통신   1.6
# 기업7      화학   0.7
# 기업8     바이오  15.0
# 기업9     반도체   2.0
# 기업10     통신   1.6
# 기업11     화학   0.7
# 기업12    플랫폼   4.0
# 기업13    바이오   2.0
# 기업14    바이오  10.0
# 기업15     통신   1.6
# 기업16    반도체   0.9
# 기업17    반도체   2.1
# 기업18    플랫폼   2.5
# 기업19     화학   1.1
# 기업20     화학   0.4
# 기업21    반도체   1.6
# 기업22    플랫폼   4.2
# 기업23     통신   1.3
# 기업24     화학   0.6
# 기업25    바이오  12.0

# %%
 df.groupby(['Sector']) # 그냥 Group만 해서는 데이터 나타나지 않는다.

# %%
df.groupby(['Sector']).count()
# Out:
#         PER
# Sector
# 바이오       5
# 반도체       5
# 통신        5
# 플랫폼       4
# 화학        6

# %% [markdown]
# ### dataFrame.groupby(['열']).mean()

# %%
 df.groupby(['Sector']).mean()
# Out:
#              PER
# Sector
# 바이오     9.800000
# 반도체     1.620000
# 통신      1.440000
# 플랫폼     3.425000
# 화학      0.666667

# %%
df.groupby(['Sector']).mean().loc['화학'].values[0]
# Out:
# 0.6666666666666666

# %%
undervalued_mean = df.groupby(['Sector']).mean().loc['화학'].values[0]
undervalued_mean
# Out:
# 0.6666666666666666

# %% [markdown]
# ### Q) 'PER' 기준 저평가된 섹터의 평균을 구하고, 섹터 평균보다 낮은 기업은?

# %% [markdown]
# 주어진 데이터에서 1)Sector별 PER를 구하고 2)그 기준으로 그보다 낮은 기업을 찾는다.

# %%
df['Sector'] == '화학'
# Out:
# 기업
# 기업1     False
# 기업2     False
# 기업3      True
# 기업4     False
# 기업5     False
# 기업6     False
# 기업7      True
# 기업8     False
# 기업9     False
# 기업10    False
# 기업11     True
# 기업12    False
# 기업13    False
# 기업14    False
# 기업15    False
# 기업16    False
# 기업17    False
# 기업18    False
# 기업19     True
# 기업20     True
# 기업21    False
# 기업22    False
# 기업23    False
# 기업24     True
# 기업25    False
# Name: Sector, dtype: bool

# %%
df_che = df[df['Sector'] == '화학']
df_che
# Out:
#      Sector  PER
# 기업
# 기업3      화학  0.5
# 기업7      화학  0.7
# 기업11     화학  0.7
# 기업19     화학  1.1
# 기업20     화학  0.4
# 기업24     화학  0.6

# %%
df_che['PER']<=undervalued_mean
# Out:
# 기업
# 기업3      True
# 기업7     False
# 기업11    False
# 기업19    False
# 기업20     True
# 기업24     True
# Name: PER, dtype: bool

# %% [markdown]
# 화사 이름을 뽑으려고 하면 'Condition' 열을 만들어 구분 값 넣는다?

# %%
df_che = df[df['Sector'] == '화학']
df_che['Condition'] = np.where(df_che['PER']<=undervalued_mean,1,np.nan)
df_che
# Out:
# C:\Users\proyj\AppData\Local\Temp\ipykernel_2380\1783717603.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_che['Condition'] = np.where(df_che['PER']<=undervalued_mean,1,np.nan)
#      Sector  PER  Condition
# 기업
# 기업3      화학  0.5        1.0
# 기업7      화학  0.7        NaN
# 기업11     화학  0.7        NaN
# 기업19     화학  1.1        NaN
# 기업20     화학  0.4        1.0
# 기업24     화학  0.6        1.0

# %%
df_che.dropna().index
# Out:
# C:\Users\proyj\AppData\Local\Temp\ipykernel_2380\1472975491.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_che['Condition'] = np.where(df_che['PER']<=undervalued_mean,1,np.nan)
# Index(['기업3', '기업20', '기업24'], dtype='object', name='기업')

# %% [markdown]
# ## 더 공부해 볼 것

# %% [markdown]
# join, merge, aggregate
